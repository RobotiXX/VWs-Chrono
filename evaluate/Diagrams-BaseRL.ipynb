# %% [markdown]
# Test Stage-based RL

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from gym_chrono.envs.wheeled.off_road_artACL import off_road_art
from gymnasium.utils.env_checker import check_env
import torch as th
import numpy as np
import os
import re
import matplotlib.pyplot as plt
import csv
from torch.utils.tensorboard import SummaryWriter

def evaluate_model(env, model, num_trials=50, max_steps=1000, render=False):
    success_count = 0
    traversal_times = []
    episode_roll_means = []
    episode_pitch_means = []

    for trial in range(num_trials):
        obs, _ = env.reset(seed=trial)
        if render:
            env.render('follow')
        
        step_count = 0
        roll_angles = []
        pitch_angles = []
        
        while step_count < max_steps:
            action, _states = model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, info = env.step(action)
            if render:
                env.render('follow')
            
            step_count += 1
            
            # Collect roll and pitch angles at each step
            euler_angles = env.m_vehicle.GetVehicle().GetRot().Q_to_Euler123()
            roll_angles.append(np.degrees(abs(euler_angles.x)))
            pitch_angles.append(np.degrees(abs(euler_angles.y)))
            
            if terminated or truncated:
                if terminated and step_count < 200:  # Successful trial
                    success_count += 1
                    traversal_times.append(env.m_system.GetChTime())
                break
        
        # Calculate mean roll and pitch angles for this episode
        episode_roll_means.append(np.mean(roll_angles))
        episode_pitch_means.append(np.mean(pitch_angles))

    mean_traversal_time = np.mean(traversal_times) if traversal_times else 0
    var_traversal_time = np.var(traversal_times) if traversal_times else 0
    avg_roll_angle = np.mean(episode_roll_means)
    var_roll_angle = np.var(episode_roll_means)
    avg_pitch_angle = np.mean(episode_pitch_means)
    var_pitch_angle = np.var(episode_pitch_means)

    return success_count, mean_traversal_time, var_traversal_time, avg_roll_angle, var_roll_angle, avg_pitch_angle, var_pitch_angle

'''
Loops over test level 5, calculates the success rate for level 5, 
and returns the mean success rate.
'''
def evaluate_on_test_levels(env, model, test_level_dir, num_trials=50, max_steps=1000, render=False, writer=None, iteration=None):
    level_file = "level_5.bmp"
    level_path = os.path.join(test_level_dir, level_file)
    env.terrain_file = [level_path]
    env.update_terrain_stage(level_index=0)
        
    # Evaluate a single model on a given terrain
    success_count, mean_traversal_time, var_traversal_time, avg_roll_angle, var_roll_angle, avg_pitch_angle, var_pitch_angle = evaluate_model(env, model, num_trials=num_trials, max_steps=max_steps, render=render)
    success_rate = float(success_count) / num_trials
    
    # Log the success rate for each test level
    if writer is not None and iteration is not None:
        writer.add_scalar(f'Success Rate/Test Level 5', success_rate, iteration)
    
    print(f"Test Level {level_file}: Success rate = {success_rate}\n")
    print(f"Mean Traversal Time: {mean_traversal_time:.2f} s", f"Average Roll/Pitch Angle: {avg_roll_angle:.2f}/{avg_pitch_angle:.2f} deg\n")
    print(f"Average Roll/Pitch Angle: {avg_roll_angle:.2f}/{avg_pitch_angle:.2f} deg")
    print(f"Variance Roll/Pitch Angle: {var_roll_angle:.2f}/{var_pitch_angle:.2f} deg\n")

    return success_rate, mean_traversal_time, var_traversal_time, avg_roll_angle, var_roll_angle, avg_pitch_angle, var_pitch_angle


# Loops through all the checkpoint files, evaluates each model on all test levels
def evaluate_checkpoints_on_test_levels(checkpoint_dir, test_level_dir, env, writer, csv_file, eval_interval=2, last_evaluated_iter=0):
    model_files = [f for f in os.listdir(checkpoint_dir) if f.endswith('.zip')]
    model_files = sorted(model_files, key=lambda f: int(re.search(r'iter(\d+)', f).group(1)))

    overall_success_rates = []
    iteration_numbers = []

    with open(csv_file, mode='w', newline='') as file:
        writer_csv = csv.writer(file)
        writer_csv.writerow(["Iteration", "Success Rate", "Mean Traversal Time", "Var Traversal Time", "Average Roll Angle", "Var Roll Angle", "Average Pitch Angle", "Var Pitch Angle"])
    
        for model_file in model_files:
            iteration = int(re.search(r'iter(\d+)', model_file).group(1))
            if iteration % eval_interval != 0:
                continue
            
            print(f"Evaluating {model_file}")
            model = PPO.load(os.path.join(checkpoint_dir, model_file), env)
            
            success_rate, mean_traversal_time, var_traversal_time, avg_roll_angle, var_roll_angle, avg_pitch_angle, var_pitch_angle = evaluate_on_test_levels(
                env, model, test_level_dir, num_trials=50, max_steps=1000, render=False, writer=writer, iteration=iteration)
            writer_csv.writerow([iteration, success_rate, mean_traversal_time, var_traversal_time, avg_roll_angle, var_roll_angle, avg_pitch_angle, var_pitch_angle])
            
            overall_success_rates.append(success_rate)
            iteration_numbers.append(iteration)
            
            print(f"Checkpoint {model_file}: Success rate on test level 5 = {success_rate}\n")
    
    mean_success_rate = np.mean(overall_success_rates)
    print(f"Mean success rate across all evaluated checkpoints = {mean_success_rate}")
    
    return iteration_numbers, overall_success_rates, mean_success_rate

# Set up TensorBoard writer
checkpoint_dir = '../train/logs/vws_ppo_checkpoints_BaseRL/'
test_level_dir = '../TestLevels'
last_evaluated_iter = 0

for run_index in range(1, 4):  # Run 3 evaluations
    log_dir = f'./BaseRLTest_logs/run{run_index}'
    writer = SummaryWriter(log_dir)
    
    env = off_road_art()
    csv_file = f'./BaseRLTest_logs/run{run_index}.csv'
    
    iteration_numbers, overall_success_rates, mean_success_rate = evaluate_checkpoints_on_test_levels(
        checkpoint_dir, test_level_dir, env, writer, csv_file, eval_interval=2, last_evaluated_iter=last_evaluated_iter)
    
    print(f"Overall success rates for all checkpoints in run {run_index}:", overall_success_rates)
    print(f"Mean success rate across all evaluated checkpoints in run {run_index}: {mean_success_rate}")
    
    writer.close()
# Out:
# Evaluating ppo_checkpoint_iter0_level49.zip
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Terrain loaded from /home/tong/Documents/gym_chrono/envs/wheeled/../data/terrain_bitmaps/Automatic-CL/TrainLevels/../TestLevels/level_5.bmp
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.87322, 6.94711, 3 ]
# Final position of art:  [ 1.92636, -0.407142, 2.84628 ]
# Goal position:  [ -10.4803, 0.642897, 2.5 ]
# Distance to goal:  12.455834706903207
# Reward:  -234.5575997519418
# Accumulated Reward:  -1273.9303447608781
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.55539, -9.87974, 3 ]
# Final position of art:  [ 5.45946, -9.32216, 2.38377 ]
# Goal position:  [ 0.803428, 10.4692, 2.5 ]
# Distance to goal:  20.332015090216164
# Reward:  -303.9328563728093
# Accumulated Reward:  -827.883289824935
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.08561, -7.74882, 3 ]
# Final position of art:  [ 2.9018, -2.45037, 2.81933 ]
# Goal position:  [ -2.11107, 10.2495, 3 ]
# Distance to goal:  13.654583323405387
# Reward:  -246.54944990918312
# Accumulated Reward:  -1242.1374257136715
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 5.18886, 10.0041, 3 ]
# Goal position:  [ -6.72306, -10.1976, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.75469, -8.78257, 3 ]
# Final position of art:  [ 7.44527, -8.50571, 2.26803 ]
# Goal position:  [ 0.700285, 10.4766, 2.5 ]
# Distance to goal:  20.146401633064542
# Reward:  -311.4683029942022
# Accumulated Reward:  -1705.3684494534427
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4571, 0.948134, 3 ]
# Final position of art:  [ 2.18834, -1.30867, 2.88978 ]
# Goal position:  [ -7.04821, 7.78285, 2.5 ]
# Distance to goal:  12.966166078433062
# Reward:  -239.65662939390853
# Accumulated Reward:  -1296.4906626748111
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.0382, -3.07976, 3 ]
# Final position of art:  [ 4.06728, -0.981349, 2.55163 ]
# Goal position:  [ -9.53218, -4.40312, 2.5 ]
# Distance to goal:  14.023426373618205
# Reward:  -250.2335489543652
# Accumulated Reward:  -1382.8906100141926
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.134, 2.74804, 3 ]
# Final position of art:  [ 5.51512, 0.454735, 2.19784 ]
# Goal position:  [ -9.10788, -5.22461, 2.5 ]
# Distance to goal:  15.690072118924725
# Reward:  -266.936262072642
# Accumulated Reward:  -1529.2265372227937
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.13483, -7.70352, 3 ]
# Final position of art:  [ 3.15158, -2.39557, 2.72367 ]
# Goal position:  [ 0.285324, 10.4961, 2.5 ]
# Distance to goal:  13.208376716154655
# Reward:  -242.08515930242697
# Accumulated Reward:  -1302.6980857252336
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.4921, -4.48889, 3 ]
# Final position of art:  [ 2.26011, -0.154886, 2.63347 ]
# Goal position:  [ -9.49224, -0.0907903, 3 ]
# Distance to goal:  11.758243761565693
# Reward:  -227.569730456659
# Accumulated Reward:  -1002.90861370213
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.06791, -10.0418, 3 ]
# Final position of art:  [ 2.79053, -2.97042, 2.78686 ]
# Goal position:  [ -9.73171, 6.69365, 3 ]
# Distance to goal:  15.819168093477455
# Reward:  -268.1916626514873
# Accumulated Reward:  -1514.614550877171
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.8817, -3.55004, 3 ]
# Final position of art:  [ 5.44767, -1.83231, 2.40482 ]
# Goal position:  [ -9.44169, 8.44566, 3 ]
# Distance to goal:  18.102042354400627
# Reward:  -291.1185998166053
# Accumulated Reward:  -1585.6380031099557
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.42609, 8.30394, 3 ]
# Final position of art:  [ 2.75699, -1.65133, 2.8231 ]
# Goal position:  [ -3.63862, -9.19541, 3 ]
# Distance to goal:  9.891830218048137
# Reward:  -208.91824567348016
# Accumulated Reward:  -1043.4908306173536
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.98808, 9.23954, 3 ]
# Final position of art:  [ 3.24885, -3.21141, 2.51191 ]
# Goal position:  [ -4.84821, -9.9348, 3 ]
# Distance to goal:  10.535868891984927
# Reward:  -215.35866118560733
# Accumulated Reward:  -1048.53650483614
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.83029, -9.77645, 3 ]
# Final position of art:  [ 4.48936, -6.07635, 2.22316 ]
# Goal position:  [ -7.11657, 7.72039, 2.5 ]
# Distance to goal:  18.031203125070398
# Reward:  -290.3284691162438
# Accumulated Reward:  -1625.7045321859819
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.4045, 6.29401, 3 ]
# Final position of art:  [ 5.03541, 0.671225, 2.32084 ]
# Goal position:  [ -10.2556, -2.25232, 2.5 ]
# Distance to goal:  15.569005640921153
# Reward:  -265.68753876805533
# Accumulated Reward:  -1468.3824163963905
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.82033, -7.0066, 3 ]
# Final position of art:  [ -3.24187, 12.9204, 2.22363 ]
# Goal position:  [ -7.43794, 10.2737, 3 ]
# Distance to goal:  5.021396164946687
# Reward:  -160.34062970185573
# Accumulated Reward:  216.96469902413799
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.89739, 10.4616, 3 ]
# Final position of art:  [ 4.46052, -1.51466, 2.25448 ]
# Goal position:  [ -9.99455, -7.69365, 3 ]
# Distance to goal:  15.738006541664317
# Reward:  -267.3801411882096
# Accumulated Reward:  -1253.2968878055115
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 3.2549, 10.4247, 3 ]
# Final position of art:  [ 4.23184, -1.0118, 2.33482 ]
# Goal position:  [ -8.65651, -8.61609, 3 ]
# Distance to goal:  14.979228056293124
# Reward:  -259.7919320178832
# Accumulated Reward:  -1148.2547359985094
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.55391, -8.20343, 3 ]
# Final position of art:  [ 6.61701, -6.27454, 2.3248 ]
# Goal position:  [ -10.0374, 3.08241, 2.5 ]
# Distance to goal:  19.10370642863334
# Reward:  -301.0363953298361
# Accumulated Reward:  -2030.8300731480135
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.87225, 9.30114, 3 ]
# Final position of art:  [ 3.57058, -0.0838002, 2.3983 ]
# Goal position:  [ -4.17595, -9.31036, 3 ]
# Distance to goal:  12.062343313203192
# Reward:  -230.69349951832555
# Accumulated Reward:  -1224.3682400155067
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.41587, -9.92884, 3 ]
# Final position of art:  [ 4.28833, -4.57363, 2.33815 ]
# Goal position:  [ -10.1608, 8.46542, 3 ]
# Distance to goal:  19.4738660981584
# Reward:  -304.70644552980843
# Accumulated Reward:  -1645.7842852579822
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.91228, -10.4603, 3 ]
# Final position of art:  [ -11.544, 8.54038, 2.48934 ]
# Goal position:  [ -5.21397, 9.11398, 2.5 ]
# Distance to goal:  6.355949769186799
# Reward:  -168.99786862644942
# Accumulated Reward:  -79.16081747877958
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.74944, -9.80774, 3 ]
# Final position of art:  [ 4.28146, -4.58214, 2.3462 ]
# Goal position:  [ 2.1076, 10.4098, 3 ]
# Distance to goal:  15.162780941778742
# Reward:  -261.6247203680945
# Accumulated Reward:  -1325.3155345414252
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.8227, 5.69297, 3 ]
# Final position of art:  [ 9.39098, 4.8273, 2.2645 ]
# Goal position:  [ -10.4734, 0.747166, 2.5 ]
# Distance to goal:  20.28043176988516
# Reward:  -312.79789510683673
# Accumulated Reward:  -2085.729203590918
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.41798, -7.43126, 3 ]
# Final position of art:  [ 5.01129, -3.5613, 2.46303 ]
# Goal position:  [ -6.91309, 5.18297, 3 ]
# Distance to goal:  14.796669425064492
# Reward:  -257.91871294750064
# Accumulated Reward:  -1418.7006301253655
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.9487, 3.35749, 3 ]
# Final position of art:  [ 1.23473, 0.210449, 2.61701 ]
# Goal position:  [ -9.78832, -3.79984, 2.5 ]
# Distance to goal:  11.730466620963911
# Reward:  -227.29727087520484
# Accumulated Reward:  -1019.590755505886
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.0985, 2.8758, 3 ]
# Final position of art:  [ 5.5423, 0.380154, 2.19582 ]
# Goal position:  [ -10.4092, -1.37787, 2.5 ]
# Distance to goal:  16.050971766955456
# Reward:  -270.5460666670529
# Accumulated Reward:  -1510.0208791746459
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.12262, 10.2832, 3 ]
# Final position of art:  [ 2.62686, 1.96386, 2.31669 ]
# Goal position:  [ 10.3174, -8.75902, 3 ]
# Distance to goal:  13.213314855873056
# Reward:  -242.14619655199508
# Accumulated Reward:  -1483.9599011794423
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.02994, 10.0533, 3 ]
# Final position of art:  [ 2.58161, -1.42237, 2.84703 ]
# Goal position:  [ -1.15832, -10.4359, 2.5 ]
# Distance to goal:  9.764809213767354
# Reward:  -207.65065023139135
# Accumulated Reward:  -997.928076586777
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.97938, 10.0684, 3 ]
# Final position of art:  [ 2.81497, 1.52966, 2.53616 ]
# Goal position:  [ -8.14086, -9.65743, 3 ]
# Distance to goal:  15.665127152711651
# Reward:  -266.7115385151024
# Accumulated Reward:  -1418.059113380447
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.05694, 10.4998, 3 ]
# Final position of art:  [ 4.15711, -3.3726, 2.31953 ]
# Goal position:  [ -2.93619, -10.0811, 2.5 ]
# Distance to goal:  9.764815357722425
# Reward:  -207.5937271619863
# Accumulated Reward:  -779.0580572249983
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.3672, 1.66483, 3 ]
# Final position of art:  [ 5.41208, 0.676174, 2.23149 ]
# Goal position:  [ -6.76821, 8.02754, 2.5 ]
# Distance to goal:  14.229341358127453
# Reward:  -252.27846567056034
# Accumulated Reward:  -1507.3217610896281
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.9978, -3.20842, 3 ]
# Final position of art:  [ 5.44363, -1.83157, 2.40327 ]
# Goal position:  [ -10.2078, -2.45991, 2.5 ]
# Distance to goal:  15.664324432209927
# Reward:  -266.6509769995105
# Accumulated Reward:  -1311.0772244697737
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.85972, 8.71285, 3 ]
# Final position of art:  [ 2.61218, 1.27184, 2.47635 ]
# Goal position:  [ -9.0258, -5.36516, 2.5 ]
# Distance to goal:  13.39749683562621
# Reward:  -243.9741059866251
# Accumulated Reward:  -1346.7406195105486
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.5128, 4.44476, 3 ]
# Final position of art:  [ 0.0327525, -0.692477, 2.30036 ]
# Goal position:  [ -9.02457, -5.32085, 3 ]
# Distance to goal:  10.195413468951017
# Reward:  -211.95419380790568
# Accumulated Reward:  -969.6619800347444
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.18382, 8.48589, 3 ]
# Final position of art:  [ 3.43971, -3.21444, 2.40475 ]
# Goal position:  [ -4.07379, -9.67751, 2.5 ]
# Distance to goal:  9.911259200104553
# Reward:  -209.09529918884297
# Accumulated Reward:  -831.2494028384831
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4993, -0.118333, 3 ]
# Final position of art:  [ 2.27235, -0.887099, 2.86663 ]
# Goal position:  [ -7.81499, -9.88505, 3 ]
# Distance to goal:  13.517958046844004
# Reward:  -245.18091117262583
# Accumulated Reward:  -1316.52778161103
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.33414, 7.51401, 3 ]
# Final position of art:  [ 3.02449, -1.96799, 2.75544 ]
# Goal position:  [ -10.4995, -0.105225, 2.5 ]
# Distance to goal:  13.654038809987014
# Reward:  -246.53941360322847
# Accumulated Reward:  -1228.8472336911232
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.19572, -10.2679, 3 ]
# Final position of art:  [ 2.45901, -3.28119, 2.82685 ]
# Goal position:  [ -6.77683, 8.02026, 2.5 ]
# Distance to goal:  14.598983147401619
# Reward:  -255.98956508132747
# Accumulated Reward:  -1531.6273239211341
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 11.6973, 4.02644, 3 ]
# Goal position:  [ -5.80824, -8.74725, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.7097, 10.476, 3 ]
# Final position of art:  [ 4.02034, -3.38232, 2.34705 ]
# Goal position:  [ 0.860699, -9.66497, 3 ]
# Distance to goal:  7.0626709959541465
# Reward:  -180.39634527823273
# Accumulated Reward:  -653.3074121849935
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.40311, 8.32167, 3 ]
# Final position of art:  [ 2.60259, -1.48996, 2.81933 ]
# Goal position:  [ -1.12163, -10.4399, 2.5 ]
# Distance to goal:  9.699151658473314
# Reward:  -206.99122828793327
# Accumulated Reward:  -1052.0518497480127
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.18852, 7.65344, 3 ]
# Final position of art:  [ 1.83502, -0.451956, 2.8616 ]
# Goal position:  [ -1.70261, -10.361, 2.5 ]
# Distance to goal:  10.527843766289589
# Reward:  -215.27470396101916
# Accumulated Reward:  -981.2574086173076
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.3066, 2.00573, 3 ]
# Final position of art:  [ 5.51995, 0.403607, 2.21215 ]
# Goal position:  [ -5.40432, -9.00241, 2.5 ]
# Distance to goal:  14.41858673220146
# Reward:  -254.19147126974116
# Accumulated Reward:  -1544.4641169472682
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.6717, -4.08762, 3 ]
# Final position of art:  [ 5.39831, -1.96967, 2.44401 ]
# Goal position:  [ -3.98843, 9.713, 2.5 ]
# Distance to goal:  14.986627653603044
# Reward:  -259.86395879105174
# Accumulated Reward:  -1237.5735631940402
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.9302, -3.41184, 3 ]
# Final position of art:  [ 5.44933, -1.83142, 2.40428 ]
# Goal position:  [ -6.39808, 8.32554, 2.5 ]
# Distance to goal:  15.605581321095672
# Reward:  -266.1024860780757
# Accumulated Reward:  -1280.292482587378
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.47514, -9.49859, 3 ]
# Final position of art:  [ 4.71537, -6.31366, 2.24216 ]
# Goal position:  [ -3.27821, 9.97514, 2.5 ]
# Distance to goal:  18.146307557406807
# Reward:  -291.0447431600205
# Accumulated Reward:  -871.591356743326
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.6514, -4.13525, 3 ]
# Final position of art:  [ 5.24227, -1.67529, 2.55838 ]
# Goal position:  [ -8.7969, -5.73275, 2.5 ]
# Distance to goal:  14.613861215132466
# Reward:  -256.13978281819664
# Accumulated Reward:  -1003.1599621145695
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 3.48107, 10.395, 3 ]
# Final position of art:  [ 2.87402, 1.81526, 2.33795 ]
# Goal position:  [ -2.98937, -10.0655, 2.5 ]
# Distance to goal:  13.249806207292394
# Reward:  -242.4951854596432
# Accumulated Reward:  -954.1927654168207
# --------------------------------------------------------------
# Test Level level_5.bmp: Success rate = 0.04
#
# Mean Traversal Time: 10.50 s Average Roll/Pitch Angle: 8.35/6.06 deg
#
# Average Roll/Pitch Angle: 8.35/6.06 deg
# Variance Roll/Pitch Angle: 30.59/22.61 deg
#
# Checkpoint ppo_checkpoint_iter0_level49.zip: Success rate on test level 5 = 0.04
#
# Evaluating ppo_checkpoint_iter2_level53.zip
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Terrain loaded from /home/tong/Documents/gym_chrono/envs/wheeled/../data/terrain_bitmaps/Automatic-CL/TrainLevels/../TestLevels/level_5.bmp
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.5931, -4.26881, 3 ]
# Final position of art:  [ 3.89348, -1.26935, 2.63717 ]
# Goal position:  [ -9.71525, -3.98295, 2.5 ]
# Distance to goal:  13.877317529038955
# Reward:  -248.77300717740377
# Accumulated Reward:  -1349.101182023348
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.24924, 9.98461, 3 ]
# Final position of art:  [ 1.46817, 1.97565, 2.30962 ]
# Goal position:  [ -7.9927, -6.80932, 2.5 ]
# Distance to goal:  12.912005777588849
# Reward:  -239.30205461492324
# Accumulated Reward:  -1287.6058014433459
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.411, 1.36451, 3 ]
# Final position of art:  [ 8.64267, 1.12254, 2.16463 ]
# Goal position:  [ -10.4633, 0.876884, 2.5 ]
# Distance to goal:  19.11051292548606
# Reward:  -301.12843033237255
# Accumulated Reward:  -1734.9068055313269
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.15011, -9.64503, 3 ]
# Final position of art:  [ 4.681, -6.91878, 2.16276 ]
# Goal position:  [ -7.02471, 10.2464, 3 ]
# Distance to goal:  20.793432971409366
# Reward:  -317.93418452152406
# Accumulated Reward:  -1667.372306319169
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.0766, 5.2787, 3 ]
# Final position of art:  [ 2.43804, -0.107943, 2.83629 ]
# Goal position:  [ -9.28344, -4.90589, 2.5 ]
# Distance to goal:  12.669901089640273
# Reward:  -236.69888239507156
# Accumulated Reward:  -1004.1642575734942
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 4.83564, 10.1099, 3 ]
# Goal position:  [ -2.56514, -10.1818, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.01166, -8.60872, 3 ]
# Final position of art:  [ 8.02671, -8.57401, 2.21407 ]
# Goal position:  [ -2.41656, 9.65643, 3 ]
# Distance to goal:  21.024475556965527
# Reward:  -320.2459751066708
# Accumulated Reward:  -2282.582509747853
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.96142, 6.84586, 3 ]
# Final position of art:  [ 2.02917, -0.665027, 2.90195 ]
# Goal position:  [ -6.82695, -9.4042, 3 ]
# Distance to goal:  12.442412582463353
# Reward:  -234.42413000742027
# Accumulated Reward:  -1231.051142339662
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.2867, -2.10558, 3 ]
# Final position of art:  [ 4.02531, -0.778522, 2.50371 ]
# Goal position:  [ -10.4783, -0.67407, 2.5 ]
# Distance to goal:  14.504022643844221
# Reward:  -255.0495717820554
# Accumulated Reward:  -981.9641351582003
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.6504, -4.13762, 3 ]
# Final position of art:  [ 4.39938, -1.38072, 2.68555 ]
# Goal position:  [ -9.4003, 4.67808, 2.5 ]
# Distance to goal:  15.072314782775662
# Reward:  -260.72454624891986
# Accumulated Reward:  -955.4772010268489
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.43295, 10.2142, 3 ]
# Final position of art:  [ -6.59382, -12.1228, 2.17079 ]
# Goal position:  [ -9.13014, -8.58026, 3 ]
# Distance to goal:  4.435081152653268
# Reward:  -154.3810859585804
# Accumulated Reward:  -29.805482273035025
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.3877, -4.70339, 3 ]
# Final position of art:  [ 5.70564, -2.43176, 2.40315 ]
# Goal position:  [ -8.54432, 6.10284, 2.5 ]
# Distance to goal:  16.610541221623542
# Reward:  -275.95730866903307
# Accumulated Reward:  -1445.0785168360899
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.2433, -4.98104, 3 ]
# Final position of art:  [ 5.67125, -2.52043, 2.39386 ]
# Goal position:  [ -8.47361, 8.16737, 3 ]
# Distance to goal:  17.739045840044856
# Reward:  -287.3641662108698
# Accumulated Reward:  -1582.1103226570435
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.4642, 4.5475, 3 ]
# Final position of art:  [ -0.122941, 0.269849, 2.22611 ]
# Goal position:  [ -9.31691, -4.84202, 2.5 ]
# Distance to goal:  10.523085071330618
# Reward:  -215.22429195115075
# Accumulated Reward:  -932.6490019438957
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.7762, -3.83083, 3 ]
# Final position of art:  [ 5.69303, -2.06693, 2.33624 ]
# Goal position:  [ -8.19329, -6.8929, 3 ]
# Distance to goal:  14.715988431661279
# Reward:  -246.58966319820945
# Accumulated Reward:  -1094.608054386169
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.9239, 3.43029, 3 ]
# Final position of art:  [ -12.4147, -1.6835, 2.3895 ]
# Goal position:  [ -10.0251, 3.12194, 2.5 ]
# Distance to goal:  5.367907086551668
# Reward:  -163.8267415499304
# Accumulated Reward:  23.25826943576874
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.2158, -2.42628, 3 ]
# Final position of art:  [ 4.11274, -0.896603, 2.56436 ]
# Goal position:  [ -9.41446, -8.27366, 3 ]
# Distance to goal:  15.414148643220514
# Reward:  -253.04344271556647
# Accumulated Reward:  -605.8239806178094
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.94216, -6.8682, 3 ]
# Final position of art:  [ 4.71782, -1.95614, 2.58911 ]
# Goal position:  [ -10.4127, -0.150962, 3 ]
# Distance to goal:  15.24333858973518
# Reward:  -262.43166143498127
# Accumulated Reward:  -915.402068480178
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.4598, 4.55657, 3 ]
# Final position of art:  [ 3.02667, 1.22901, 2.47888 ]
# Goal position:  [ -8.57992, 6.05268, 2.5 ]
# Distance to goal:  12.569057820753661
# Reward:  -235.68093168316335
# Accumulated Reward:  -1231.150037641606
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.8236, 9.77906, 3 ]
# Final position of art:  [ 2.17043, -1.16399, 2.96887 ]
# Goal position:  [ 2.51916, -10.1933, 2.5 ]
# Distance to goal:  9.048223179851236
# Reward:  -200.48242375707298
# Accumulated Reward:  -1142.808286119201
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.20297, 10.2663, 3 ]
# Final position of art:  [ 1.65078, 1.94923, 2.21822 ]
# Goal position:  [ -0.769643, -10.4718, 2.5 ]
# Distance to goal:  12.657758679794238
# Reward:  -236.53004353064387
# Accumulated Reward:  -1335.325049270774
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.4647, 4.5463, 3 ]
# Final position of art:  [ -0.00449809, -0.581345, 2.29419 ]
# Goal position:  [ -6.82767, -7.97703, 2.5 ]
# Distance to goal:  10.064497261303082
# Reward:  -210.627035612792
# Accumulated Reward:  -962.4931222580595
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.90147, 10.4612, 3 ]
# Final position of art:  [ 3.07349, 1.67469, 2.31092 ]
# Goal position:  [ -7.75001, -7.08431, 2.5 ]
# Distance to goal:  13.924930525249751
# Reward:  -249.26478212850833
# Accumulated Reward:  -1231.1199426735725
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.31399, -7.53363, 3 ]
# Final position of art:  [ 2.98567, -2.41152, 2.79111 ]
# Goal position:  [ -10.474, 0.73848, 2.5 ]
# Distance to goal:  13.826422228210065
# Reward:  -248.26417705269876
# Accumulated Reward:  -1419.1937228577485
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.83425, -6.99103, 3 ]
# Final position of art:  [ 3.91687, -0.358092, 2.40757 ]
# Goal position:  [ -4.40436, 9.53161, 2.5 ]
# Distance to goal:  12.925081145452022
# Reward:  -239.250717508281
# Accumulated Reward:  -1307.1284136330817
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.1042, -5.23104, 3 ]
# Final position of art:  [ 4.87154, -2.3439, 2.79323 ]
# Goal position:  [ -5.72773, 8.80018, 2.5 ]
# Distance to goal:  15.382487969615939
# Reward:  -263.8089934125529
# Accumulated Reward:  -1439.4498449726348
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.26992, 9.08174, 3 ]
# Final position of art:  [ 3.89475, 1.77512, 2.28095 ]
# Goal position:  [ -0.200859, -10.4981, 2.5 ]
# Distance to goal:  12.940381939362096
# Reward:  -239.3639167404212
# Accumulated Reward:  -1370.7055423856236
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.2518, -6.49292, 3 ]
# Final position of art:  [ 5.26959, -3.14901, 2.38791 ]
# Goal position:  [ -8.06691, 6.72123, 2.5 ]
# Distance to goal:  16.59205530515727
# Reward:  -265.30702891591244
# Accumulated Reward:  -727.7757855603166
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.36856, -8.34814, 3 ]
# Final position of art:  [ 6.62865, -6.36485, 2.31905 ]
# Goal position:  [ -8.79156, 5.74094, 2.5 ]
# Distance to goal:  19.605256894124384
# Reward:  -306.0525620513156
# Accumulated Reward:  -2028.3180934965944
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.15927, 10.4988, 3 ]
# Final position of art:  [ 3.96325, -3.38733, 2.36616 ]
# Goal position:  [ -4.42798, -9.52066, 2.5 ]
# Distance to goal:  10.394638375673676
# Reward:  -213.948817965711
# Accumulated Reward:  -937.2302981164266
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.73148, 9.81458, 3 ]
# Final position of art:  [ 2.38684, 1.85719, 2.31748 ]
# Goal position:  [ -8.38386, -7.87911, 3 ]
# Distance to goal:  14.535110100631206
# Reward:  -255.3445114558179
# Accumulated Reward:  -1083.002853994185
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.84414, -6.97993, 3 ]
# Final position of art:  [ 3.85867, -0.278559, 2.40189 ]
# Goal position:  [ -6.92091, 7.89627, 2.5 ]
# Distance to goal:  13.529105953719288
# Reward:  -245.28885754372078
# Accumulated Reward:  -1293.2973043754982
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.34947, 9.03511, 3 ]
# Final position of art:  [ 2.41435, 1.19327, 2.55036 ]
# Goal position:  [ -4.5214, -8.21814, 3 ]
# Distance to goal:  11.699643168367187
# Reward:  -227.00462670888362
# Accumulated Reward:  -1297.5962458318463
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.20607, -10.498, 3 ]
# Final position of art:  [ 2.31339, -10.4996, 2.78859 ]
# Goal position:  [ -3.0302, 10.2175, 3 ]
# Distance to goal:  21.396195570027288
# Reward:  -324.155348938782
# Accumulated Reward:  -2208.2903535845526
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.94488, -10.0786, 3 ]
# Final position of art:  [ 3.5749, -4.76752, 2.51953 ]
# Goal position:  [ -3.07157, 9.60039, 3 ]
# Distance to goal:  15.83804244519753
# Reward:  -268.4001932719889
# Accumulated Reward:  -1230.5777188946129
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.7381, -5.82198, 3 ]
# Final position of art:  [ 5.43012, -2.96168, 2.38652 ]
# Goal position:  [ -8.63121, 5.27007, 3 ]
# Distance to goal:  16.305180542804536
# Reward:  -273.0528724287859
# Accumulated Reward:  -1465.0303806785619
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.3779, -1.59644, 3 ]
# Final position of art:  [ 4.0081, -0.858419, 2.55125 ]
# Goal position:  [ -8.03114, 6.76393, 2.5 ]
# Distance to goal:  14.249424963417907
# Reward:  -241.85855603267444
# Accumulated Reward:  -403.72109929315525
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.07654, 9.19123, 3 ]
# Final position of art:  [ 3.42671, -0.15847, 2.49068 ]
# Goal position:  [ -5.14655, -9.07819, 3 ]
# Distance to goal:  12.382309643607208
# Reward:  -233.94518056725536
# Accumulated Reward:  -1256.7359270883428
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.23989, 10.4973, 3 ]
# Final position of art:  [ 4.02638, -3.3958, 2.36042 ]
# Goal position:  [ -2.80083, -9.03854, 3 ]
# Distance to goal:  8.880331529255594
# Reward:  -198.79994563466386
# Accumulated Reward:  -788.9828858728865
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.2014, 2.48621, 3 ]
# Final position of art:  [ 2.86305, -2.52658, 2.85622 ]
# Goal position:  [ -7.18791, -7.65401, 2.5 ]
# Distance to goal:  11.288901494018624
# Reward:  -222.889030776735
# Accumulated Reward:  -1165.4289672056775
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.2826, -6.45357, 3 ]
# Final position of art:  [ 2.17595, -1.38263, 2.92755 ]
# Goal position:  [ -10.4133, -1.34618, 2.5 ]
# Distance to goal:  12.59661178252542
# Reward:  -235.96581964765133
# Accumulated Reward:  -1021.9130886665952
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.84462, -8.72298, 3 ]
# Final position of art:  [ 6.00806, -6.49705, 2.24514 ]
# Goal position:  [ -8.33696, 10.145, 3 ]
# Distance to goal:  21.98424984717313
# Reward:  -329.84249329802947
# Accumulated Reward:  -1748.9659166557074
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.53, 4.40789, 3 ]
# Final position of art:  [ -0.0250213, -0.507286, 2.29929 ]
# Goal position:  [ -10.3442, 1.80229, 2.5 ]
# Distance to goal:  10.576348834214153
# Reward:  -215.75555960685045
# Accumulated Reward:  -1025.3267374070012
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.728, 7.1083, 3 ]
# Final position of art:  [ 3.25813, 1.49556, 2.31772 ]
# Goal position:  [ -10.4809, -0.632377, 2.5 ]
# Distance to goal:  13.904077013925166
# Reward:  -249.01860598717184
# Accumulated Reward:  -1404.2013805214701
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.3842, 9.93968, 3 ]
# Final position of art:  [ 2.39557, 1.86667, 2.31362 ]
# Goal position:  [ -7.7904, -8.00332, 3 ]
# Distance to goal:  14.200062818483268
# Reward:  -252.00629566501456
# Accumulated Reward:  -1111.6134361001734
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 12.4683, -0.814999, 3 ]
# Goal position:  [ -8.40634, 6.29153, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.52477, -8.92899, 3 ]
# Final position of art:  [ 5.47635, -6.49334, 2.29833 ]
# Goal position:  [ -7.69034, 4.21331, 3 ]
# Distance to goal:  16.984893565275936
# Reward:  -279.87550139505777
# Accumulated Reward:  -1146.4735195333797
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.3539, -6.36094, 3 ]
# Final position of art:  [ 10.3858, -6.54645, 2.44255 ]
# Goal position:  [ -6.50756, 7.75213, 3 ]
# Distance to goal:  22.139213117542173
# Reward:  -331.4359114936477
# Accumulated Reward:  -2281.7226386217926
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.84504, -10.1072, 3 ]
# Final position of art:  [ 3.88369, -4.704, 2.55095 ]
# Goal position:  [ -4.05818, 9.68407, 2.5 ]
# Distance to goal:  16.43448777480672
# Reward:  -274.5541764925781
# Accumulated Reward:  -1630.316724289802
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.40828, -9.00003, 3 ]
# Final position of art:  [ 6.71374, -7.80278, 2.37478 ]
# Goal position:  [ -4.76731, 9.35536, 2.5 ]
# Distance to goal:  20.64538585662854
# Reward:  -303.3569184982822
# Accumulated Reward:  -1116.5217646796036
# --------------------------------------------------------------
# Test Level level_5.bmp: Success rate = 0.04
#
# Mean Traversal Time: 8.60 s Average Roll/Pitch Angle: 9.32/4.89 deg
#
# Average Roll/Pitch Angle: 9.32/4.89 deg
# Variance Roll/Pitch Angle: 40.97/14.76 deg
#
# Checkpoint ppo_checkpoint_iter2_level53.zip: Success rate on test level 5 = 0.04
#
# Evaluating ppo_checkpoint_iter4_level33.zip
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Terrain loaded from /home/tong/Documents/gym_chrono/envs/wheeled/../data/terrain_bitmaps/Automatic-CL/TrainLevels/../TestLevels/level_5.bmp
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.049, 3.04422, 3 ]
# Final position of art:  [ 5.49014, -1.676, 2.36864 ]
# Goal position:  [ -8.03936, -8.34866, 3 ]
# Distance to goal:  15.0986845920174
# Reward:  -260.9992765406056
# Accumulated Reward:  -1163.9071624659389
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4917, -0.417531, 3 ]
# Final position of art:  [ 4.60929, -3.26492, 2.45326 ]
# Goal position:  [ -9.47231, -4.53048, 2.5 ]
# Distance to goal:  14.138435350399805
# Reward:  -251.3823077009592
# Accumulated Reward:  -1232.7144902854238
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.8676, -5.6228, 3 ]
# Final position of art:  [ 8.81021, -4.76683, 2.34328 ]
# Goal position:  [ -9.39894, 4.68081, 2.5 ]
# Distance to goal:  20.514759365191725
# Reward:  -315.10206130284587
# Accumulated Reward:  -1736.2994037529324
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.9713, -3.28994, 3 ]
# Final position of art:  [ -11.3322, 12.7433, 2.38747 ]
# Goal position:  [ -4.23318, 9.60886, 2.5 ]
# Distance to goal:  7.76107273832618
# Reward:  -187.73259068294882
# ...
# Goal position:  [ 10.0373, 9.25423, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.96916, -9.72089, 3 ]
# Final position of art:  [ 4.48688, -5.95135, 2.26144 ]
# Goal position:  [ -8.83543, 7.80662, 3 ]
# Distance to goal:  19.1653629846494
# Reward:  -301.6410382206874
# Accumulated Reward:  -1695.363559357289
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.9898, -5.42518, 3 ]
# Final position of art:  [ 5.55005, -2.84409, 2.41021 ]
# Goal position:  [ -7.16214, 10.4471, 3 ]
# Distance to goal:  18.40113921764448
# Reward:  -293.5587034098015
# Accumulated Reward:  -1520.690375222785
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 3.45341, -10.3989, 3 ]
# Goal position:  [ -9.66825, 6.16339, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.0615, -6.72766, 3 ]
# Final position of art:  [ 4.66424, -2.00674, 2.5124 ]
# Goal position:  [ -7.82405, 10.2908, 3 ]
# Distance to goal:  17.53354024441355
# Reward:  -285.36301438057166
# Accumulated Reward:  -1030.3618933346534
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.46733, 8.96428, 3 ]
# Final position of art:  [ 3.87503, 0.814912, 2.41569 ]
# Goal position:  [ -6.08525, -8.55686, 2.5 ]
# Distance to goal:  13.676409406058411
# Reward:  -246.75555254154344
# Accumulated Reward:  -1395.2386310743193
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.16718, -9.14058, 3 ]
# Final position of art:  [ 4.88146, -4.3433, 2.34035 ]
# Goal position:  [ -5.14152, 9.15504, 2.5 ]
# Distance to goal:  16.813411575602636
# Reward:  -278.1386158729479
# Accumulated Reward:  -1258.4874008155673
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.54309, 10.4859, 3 ]
# Final position of art:  [ 5.90133, -6.30826, 2.30503 ]
# Goal position:  [ 1.10559, -10.4416, 2.5 ]
# Distance to goal:  6.334191905875222
# Reward:  -173.35423105613796
# Accumulated Reward:  -713.4116090420873
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.04651, 10.4999, 3 ]
# Final position of art:  [ 9.44056, -12.1922, 2.29857 ]
# Goal position:  [ -2.64489, -10.1614, 2.5 ]
# Distance to goal:  12.256541113853848
# Reward:  -232.4496674884376
# Accumulated Reward:  -748.0462136458765
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.195, 6.56439, 3 ]
# Final position of art:  [ 2.77824, -3.24665, 2.74136 ]
# Goal position:  [ -2.90763, -10.0894, 2.5 ]
# Distance to goal:  8.900023520375626
# Reward:  -199.37609495165304
# Accumulated Reward:  -659.4774483663754
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.8214, -5.69506, 3 ]
# Final position of art:  [ 3.08699, -2.37396, 2.81779 ]
# Goal position:  [ -9.54518, 4.37487, 2.5 ]
# Distance to goal:  14.325482047218687
# Reward:  -253.25146624004987
# Accumulated Reward:  -1235.7456846578
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.2925, -2.07723, 3 ]
# Final position of art:  [ 4.8002, -0.998366, 2.50343 ]
# Goal position:  [ -7.32201, 7.52584, 2.5 ]
# Distance to goal:  14.819240323191913
# Reward:  -258.21966353228805
# Accumulated Reward:  -1159.3511789526979
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.2539, -2.26004, 3 ]
# Final position of art:  [ -12.3978, 4.37029, 2.51715 ]
# Goal position:  [ -5.70578, 9.6084, 3 ]
# Distance to goal:  8.511987047402334
# Reward:  -195.11333396907688
# Accumulated Reward:  -67.6439424815157
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.94819, 8.65269, 3 ]
# Final position of art:  [ 1.70017, -0.664881, 2.9176 ]
# Goal position:  [ -9.11288, -10.1405, 3 ]
# Distance to goal:  14.377659204564827
# Reward:  -253.77754325987618
# Accumulated Reward:  -1136.2705434070438
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.7029, 4.01285, 3 ]
# Final position of art:  [ 2.20913, -0.903662, 2.89337 ]
# Goal position:  [ -8.09637, -6.68572, 2.5 ]
# Distance to goal:  11.823285650602013
# Reward:  -228.23415494322626
# Accumulated Reward:  -906.370956380781
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.30767, 8.39424, 3 ]
# Final position of art:  [ 1.7937, -0.448415, 2.86057 ]
# Goal position:  [ -8.11616, -6.77546, 3 ]
# Distance to goal:  11.75824280542212
# Reward:  -227.58798024707244
# Accumulated Reward:  -1110.32397201288
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4848, 0.565235, 3 ]
# Final position of art:  [ 2.08821, -1.42386, 2.93624 ]
# Goal position:  [ -9.4384, 4.60072, 2.5 ]
# Distance to goal:  13.013399523810197
# Reward:  -240.13339190108331
# Accumulated Reward:  -1218.379552315217
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.022, 3.13214, 3 ]
# Final position of art:  [ -12.1969, -2.55837, 2.28958 ]
# Goal position:  [ -10.1002, 2.8698, 2.5 ]
# Distance to goal:  5.822847399461004
# Reward:  -168.23841301920135
# Accumulated Reward:  -255.3006337604545
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 2.19533, -10.4982, 3 ]
# Goal position:  [ -5.0207, 10.4417, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 3.22632, 10.4281, 3 ]
# Final position of art:  [ 4.20296, -1.39796, 2.29011 ]
# Goal position:  [ 8.5781, -9.04682, 3 ]
# Distance to goal:  8.840302302119499
# Reward:  -197.98098365620672
# Accumulated Reward:  -792.6877839954129
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.5212, 8.9312, 3 ]
# Final position of art:  [ 2.68176, 1.39566, 2.44719 ]
# Goal position:  [ -9.6508, -4.13668, 2.5 ]
# Distance to goal:  13.516712947623942
# Reward:  -245.37920488663616
# Accumulated Reward:  -1294.2953492445104
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 5.24664, 9.98546, 3 ]
# Goal position:  [ -6.63913, -9.83906, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.9323, 5.51939, 3 ]
# Final position of art:  [ 9.96548, 5.14156, 2.28036 ]
# Goal position:  [ -9.72334, -3.96316, 2.5 ]
# Distance to goal:  21.693176611080506
# Reward:  -326.9317357843224
# Accumulated Reward:  -1837.394517243342
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.56921, -10.4846, 3 ]
# Final position of art:  [ 2.759, -10.2028, 2.64735 ]
# Goal position:  [ -5.28653, 8.80339, 3 ]
# Distance to goal:  20.641910959088282
# Reward:  -316.3985833226443
# Accumulated Reward:  -2289.7672091564687
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.7842, -5.75219, 3 ]
# Final position of art:  [ 8.86617, -4.71769, 2.34845 ]
# Goal position:  [ -10.1352, 6.42575, 3 ]
# Distance to goal:  22.037563801960417
# Reward:  -330.3731466992881
# Accumulated Reward:  -1944.7059518706837
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.3422, -4.79298, 3 ]
# Final position of art:  [ 5.87714, -2.19068, 2.35229 ]
# Goal position:  [ -6.48273, 6.37175, 3 ]
# Distance to goal:  15.049962752893009
# Reward:  -260.8713648579097
# Accumulated Reward:  -1234.4626522044491
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.3642, -1.68297, 3 ]
# Final position of art:  [ 4.08514, -0.804404, 2.51914 ]
# Goal position:  [ -9.54408, 4.37727, 2.5 ]
# Distance to goal:  14.581008364433115
# Reward:  -255.6419221291743
# Accumulated Reward:  -470.3620238523114
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.6205, 8.14979, 3 ]
# Final position of art:  [ 2.91567, -1.91769, 2.79486 ]
# Goal position:  [ -9.70255, -4.01379, 2.5 ]
# Distance to goal:  12.794531208419219
# Reward:  -237.9453227649164
# Accumulated Reward:  -1270.1213439421722
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.6381, -4.16624, 3 ]
# Final position of art:  [ 1.81414, 0.169268, 2.54691 ]
# Goal position:  [ -5.25795, 9.08867, 2.5 ]
# Distance to goal:  11.382985975667804
# Reward:  -223.8491767299113
# Accumulated Reward:  -1001.3716090392259
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4875, -0.513204, 3 ]
# Final position of art:  [ 3.33008, -0.391475, 2.69972 ]
# Goal position:  [ -10.1207, 2.79659, 2.5 ]
# Distance to goal:  13.82489600335523
# Reward:  -248.19547050529167
# Accumulated Reward:  -1269.2114729271334
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4769, 0.69634, 3 ]
# Final position of art:  [ 3.15019, -2.22261, 2.7172 ]
# Goal position:  [ -9.1844, 8.65432, 3 ]
# Distance to goal:  16.447791190498574
# Reward:  -274.4768028958175
# Accumulated Reward:  -1435.5329686347782
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.2818, 2.12927, 3 ]
# Final position of art:  [ 5.51745, 0.41555, 2.21195 ]
# Goal position:  [ -6.23161, 10.0406, 3 ]
# Distance to goal:  15.208677856703199
# Reward:  -262.09040224469214
# Accumulated Reward:  -1548.1144759492292
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 4.53441, -10.1895, 3 ]
# Goal position:  [ -1.44008, 10.4008, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.1776, 5.10108, 3 ]
# Final position of art:  [ 11.2204, 5.4041, 2.33131 ]
# Goal position:  [ -10.2292, -2.36946, 2.5 ]
# Distance to goal:  22.81532112210786
# Reward:  -338.15286741557577
# Accumulated Reward:  -1937.4716924149193
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.00328, 10.3071, 3 ]
# Final position of art:  [ 4.66775, 1.15303, 2.25922 ]
# Goal position:  [ 8.67344, -10.36, 3 ]
# Distance to goal:  12.212436350245461
# Reward:  -207.9520918371099
# Accumulated Reward:  -1261.673180567535
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.58746, 9.86814, 3 ]
# Final position of art:  [ 2.80156, -1.56106, 2.82907 ]
# Goal position:  [ -2.71025, -10.1442, 2.5 ]
# Distance to goal:  10.205806457772296
# Reward:  -212.0551998228263
# Accumulated Reward:  -1101.336029763261
# --------------------------------------------------------------
# Test Level level_5.bmp: Success rate = 0.1
#
# Mean Traversal Time: 8.88 s Average Roll/Pitch Angle: 8.95/5.51 deg
#
# Average Roll/Pitch Angle: 8.95/5.51 deg
# Variance Roll/Pitch Angle: 25.25/17.87 deg
#
# Checkpoint ppo_checkpoint_iter38_level81.zip: Success rate on test level 5 = 0.1
#
# Mean success rate across all evaluated checkpoints = 0.177
# Overall success rates for all checkpoints in run 3: [0.04, 0.02, 0.2, 0.12, 0.34, 0.32, 0.2, 0.34, 0.14, 0.0, 0.02, 0.12, 0.0, 0.1, 0.02, 0.06, 0.42, 0.52, 0.46, 0.1]
# Mean success rate across all evaluated checkpoints in run 3: 0.177
