# %%
import gymnasium as gym
from stable_baselines3 import PPO
from gym_chrono.envs.wheeled.off_road_artACL import off_road_art
import numpy as np
import os
import matplotlib.pyplot as plt
from PIL import Image
from torch.utils.tensorboard import SummaryWriter

def init_trajectory_plot(bmp_image_path):
    bmp_image = Image.open(bmp_image_path)
    bmp_array = np.array(bmp_image)

    fig, ax = plt.subplots(figsize=(12, 12), dpi=300)
    ax.imshow(bmp_array, cmap='gray', alpha=1)
    ax.set_title("Vehicle Trajectories on Test Terrain", fontsize=20, color='white', fontweight='bold')
    
    # Remove X and Y labels
    ax.set_xticks([])
    ax.set_yticks([])

    # Set the figure background to black for better contrast
    fig.patch.set_facecolor('black')
    ax.set_facecolor('black')

    return fig, ax

def update_trajectory_plot(ax, trajectory, trial):
    x_coords, y_coords = zip(*trajectory)
    
    # Increase line thickness and transparency
    ax.plot(x_coords, y_coords, linewidth=1.5, alpha=0.6, color='white')  # Thicker lines with more opacity
    
    start = trajectory[0]
    end = trajectory[-1]
    
    # Solid markers for start and end (filled dot)
    ax.plot(start[0], start[1], 'o', markersize=8, markeredgecolor='white', markerfacecolor='white', alpha=0.9)  # Solid dot for start
    ax.plot(end[0], end[1], 'o', markersize=8, markeredgecolor='white', markerfacecolor='white', alpha=0.9)    # Solid dot for end

    # Update the title to show the current trial number with a bold font
    ax.set_title(f"50 Evaluation Trajectories on Test Terrain", fontsize=20, color='white', fontweight='bold')


def save_trajectory_plot(fig, output_path):
    # Tight layout to ensure the plot saves properly
    plt.tight_layout()

    # Save the figure
    plt.savefig(output_path, dpi=300, bbox_inches='tight', facecolor='black', edgecolor='none')
    print(f"Saved trajectory visualization to {output_path}")

def evaluate_model(env, model, num_trials=50, max_steps=1000, render=False, bmp_image_path=None):
    all_trajectories = []
    success_count = 0
    traversal_times = []
    episode_roll_means = []
    episode_pitch_means = []

    # Initialize the plot
    fig, ax = init_trajectory_plot(bmp_image_path)

    for trial in range(num_trials):
        obs, _ = env.reset(seed=trial)
        if render:
            env.render('follow')

        step_count = 0
        roll_angles = []
        pitch_angles = []
        trajectory = []

        while step_count < max_steps:
            action, _states = model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, info = env.step(action)
            if render:
                env.render('follow')

            # Get the vehicle's position on the bitmap image
            pos_bmp_x, pos_bmp_y = env.get_vehicle_position_on_bmp()
            trajectory.append((pos_bmp_x, pos_bmp_y))

            step_count += 1

            # Collect roll and pitch angles at each step
            euler_angles = env.m_vehicle.GetVehicle().GetRot().Q_to_Euler123()
            roll_angles.append(np.degrees(abs(euler_angles.x)))
            pitch_angles.append(np.degrees(abs(euler_angles.y)))

            if terminated or truncated:
                if terminated and step_count < 200:  # Successful trial
                    success_count += 1
                    traversal_times.append(env.m_system.GetChTime())
                break

        all_trajectories.append(trajectory)

        # Update the plot with the new trajectory
        update_trajectory_plot(ax, trajectory, trial)

        # Save the updated plot after each trial
        save_trajectory_plot(fig, os.path.join("./PLRTest_logs/TrajEval/iter102_level18Final", f"traj{trial+1}.png"))

        # Calculate mean roll and pitch angles for this episode
        episode_roll_means.append(np.mean(roll_angles))
        episode_pitch_means.append(np.mean(pitch_angles))

    plt.close(fig)

    mean_traversal_time = np.mean(traversal_times) if traversal_times else 0
    var_traversal_time = np.var(traversal_times) if traversal_times else 0
    avg_roll_angle = np.mean(episode_roll_means)
    var_roll_angle = np.var(episode_roll_means)
    avg_pitch_angle = np.mean(episode_pitch_means)
    var_pitch_angle = np.var(episode_pitch_means)

    return all_trajectories, success_count, mean_traversal_time, var_traversal_time, avg_roll_angle, var_roll_angle, avg_pitch_angle, var_pitch_angle

def evaluate_single_model(env, model_file, test_level_dir, num_trials=50, max_steps=1000, render=False, writer=None):
    level_file = "level_5.bmp"
    level_path = os.path.join(test_level_dir, level_file)
    env.terrain_file = [level_path]
    env.update_terrain_stage(level_index=0)

    # Reset the environment to ensure everything is initialized
    env.reset()

    # Now we can safely access the bitmap_file
    actual_terrain_path = env.bitmap_file

    # Load the single model for evaluation
    model = PPO.load(model_file)

    # Evaluate the model
    all_trajectories, success_count, mean_traversal_time, var_traversal_time, avg_roll_angle, var_roll_angle, avg_pitch_angle, var_pitch_angle = evaluate_model(
        env, model, num_trials=num_trials, max_steps=max_steps, render=render, bmp_image_path=actual_terrain_path)

    success_rate = float(success_count) / num_trials

    # Log the success rate for the test level
    if writer is not None:
        writer.add_scalar(f'Success Rate/Test Level 5', success_rate, 0)  # Iteration 0 for a single model

    print(f"Test Level {level_file}: Success rate = {success_rate}\n")
    print(f"Mean Traversal Time: {mean_traversal_time:.2f} s")
    print(f"Average Roll/Pitch Angle: {avg_roll_angle:.2f}/{avg_pitch_angle:.2f} deg")
    print(f"Variance Roll/Pitch Angle: {var_roll_angle:.2f}/{var_pitch_angle:.2f} deg")

    return success_rate, mean_traversal_time, var_traversal_time, avg_roll_angle, var_roll_angle, avg_pitch_angle, var_pitch_angle

# Main function to run the simulation and evaluate the specific model
if __name__ == "__main__":
    checkpoint_dir = '../train/logs/vws_ppo_checkpoints_PLRNorm/'
    model_file = os.path.join(checkpoint_dir, "ppo_checkpoint_iter102_level18")  # Use this specific model
    test_level_dir = '../TestLevels'
    
    # Set up TensorBoard writer for logging
    log_dir = f'./PLRTest_logs/TrajEval'
    writer = SummaryWriter(log_dir)

    # Create the custom off-road environment
    env = off_road_art()
    
    # Evaluate the single model on the test level for 50 trials
    evaluate_single_model(env, model_file, test_level_dir, num_trials=50, max_steps=1000, render=False, writer=writer)

    writer.close()
# Out:
# Terrain loaded from /home/tong/Documents/gym_chrono/envs/wheeled/../data/terrain_bitmaps/Automatic-CL/TrainLevels/../TestLevels/level_5.bmp
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 10.3561, 6.3581, 3 ]
# Goal position:  [ -10.4279, 1.22851, 2.5 ]
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj1.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 7.1447, 9.15326, 3 ]
# Goal position:  [ -10.0298, -3.12348, 3 ]
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj2.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 12.1526, 2.67871, 3 ]
# Goal position:  [ -9.86566, -1.94497, 3 ]
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj3.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 12.3469, -1.78644, 3 ]
# Goal position:  [ -8.65684, 5.94215, 2.5 ]
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj4.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 12.4998, -0.0572385, 3 ]
# Goal position:  [ -8.66991, 5.92306, 2.5 ]
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj5.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.48383, -7.36494, 3 ]
# Final position of art:  [ 5.11438, -3.46307, 2.48451 ]
# Goal position:  [ -10.0053, 6.37933, 3 ]
# Distance to goal:  18.048332521812544
# Reward:  -290.60161776860224
# Accumulated Reward:  -1663.3306493059215
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj6.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.91381, -9.27925, 3 ]
# Final position of art:  [ 6.79556, -9.09426, 2.41558 ]
# Goal position:  [ -8.93373, 6.92339, 3 ]
# Distance to goal:  22.457006498718044
# Reward:  -334.57369813699984
# Accumulated Reward:  -2266.8442306427714
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj7.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.0875, -5.25998, 3 ]
# Final position of art:  [ 2.89748, -2.71141, 2.79855 ]
# Goal position:  [ -10.3429, -1.80927, 2.5 ]
# Distance to goal:  13.274480310317953
# Reward:  -242.74480177086826
# Accumulated Reward:  -1353.1730560452925
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj8.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 12.216, 2.42543, 3 ]
# Goal position:  [ -8.4284, 9.84126, 3 ]
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj9.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4312, 1.19976, 3 ]
# Final position of art:  [ -0.119844, 0.295318, 2.25173 ]
# Goal position:  [ -10.2196, -2.41033, 2.5 ]
# Distance to goal:  10.458839627045151
# Reward:  -214.58657434040006
# Accumulated Reward:  -893.8212341990135
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj10.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 10.5581, -6.08348, 3 ]
# Goal position:  [ -3.84493, 10.4282, 3 ]
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj11.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.29267, -7.55426, 3 ]
# Final position of art:  [ 2.76858, -1.70008, 2.7573 ]
# Goal position:  [ -9.40784, 2.73952, 3 ]
# Distance to goal:  12.96279537332267
# Reward:  -239.62793557782226
# Accumulated Reward:  -1253.0663844096066
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj12.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4964, -0.275207, 3 ]
# Final position of art:  [ 0.43896, 0.863009, 2.2069 ]
# Goal position:  [ -10.4423, -1.09958, 2.5 ]
# Distance to goal:  11.060684434552106
# Reward:  -220.73122892048104
# Accumulated Reward:  -918.331742719018
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj13.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.0528, -5.31956, 3 ]
# Final position of art:  [ 2.93113, -2.73932, 2.77903 ]
# Goal position:  [ -10.2275, -2.37669, 2.5 ]
# Distance to goal:  13.166562715826926
# Reward:  -241.665521172809
# Accumulated Reward:  -1277.8482196763348
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj14.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.0588, 5.30932, 3 ]
# Final position of art:  [ 10.8971, 5.51044, 2.30364 ]
# Goal position:  [ -9.9077, -3.4767, 2.5 ]
# Distance to goal:  22.66381101740412
# Reward:  -336.7240243343488
# Accumulated Reward:  -1945.482263833525
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj15.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.1796, 2.57424, 3 ]
# Final position of art:  [ 5.55056, 0.327266, 2.20853 ]
# Goal position:  [ -8.13202, -6.64231, 2.5 ]
# Distance to goal:  15.358150318078524
# Reward:  -263.60503207388496
# Accumulated Reward:  -1518.4563422595409
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj16.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.10323, -7.73266, 3 ]
# Final position of art:  [ 5.09057, -3.64525, 2.45809 ]
# Goal position:  [ -7.43692, 6.00516, 3 ]
# Distance to goal:  15.822837788053857
# Reward:  -268.5003333899907
# Accumulated Reward:  -1647.300709202524
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj17.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 8.1365, 8.52017, 3 ]
# Goal position:  [ -8.04165, -6.75144, 2.5 ]
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj18.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 3.36637, 10.4107, 3 ]
# Final position of art:  [ -2.43234, -3.16106, 2.15703 ]
# Goal position:  [ -5.38002, -10.0695, 3 ]
# Distance to goal:  7.558212716017853
# Reward:  -176.41566594832196
# Accumulated Reward:  -763.4852152714402
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj19.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.90706, -10.0895, 3 ]
# Final position of art:  [ 3.8911, -4.9321, 2.50144 ]
# Goal position:  [ -10.3952, 9.57251, 3 ]
# Distance to goal:  20.36489989362627
# Reward:  -313.6417956752821
# Accumulated Reward:  -1523.007337016535
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj20.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.9688, -3.29729, 3 ]
# Final position of art:  [ 5.36515, -2.9767, 2.43714 ]
# Goal position:  [ -7.80217, -9.96101, 3 ]
# Distance to goal:  14.915619698255265
# Reward:  -259.1564487787232
# Accumulated Reward:  -1543.9299868751061
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj21.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 11.2725, -4.9265, 3 ]
# Goal position:  [ -8.38794, 6.22435, 3 ]
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj22.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 12.4865, -0.532976, 3 ]
# Goal position:  [ -9.34933, 4.77912, 2.5 ]
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj23.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.89636, -9.28847, 3 ]
# Final position of art:  [ 6.83471, -9.05725, 2.42976 ]
# Goal position:  [ -0.112458, 10.0875, 3 ]
# Distance to goal:  20.37420727610962
# Reward:  -313.7799659930582
# Accumulated Reward:  -2234.977605384126
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj24.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.22057, -8.45899, 3 ]
# Final position of art:  [ 6.39136, -5.60368, 2.3663 ]
# Goal position:  [ -2.95434, 8.99642, 3 ]
# Distance to goal:  17.34665772032639
# Reward:  -283.4674861891302
# Accumulated Reward:  -1657.236386595171
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj25.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 3.88517, -10.3294, 3 ]
# Goal position:  [ 3.96715, 9.72171, 2.5 ]
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj26.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 2.04215, 10.4999, 3 ]
# Goal position:  [ -2.27403, -9.84099, 3 ]
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj27.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.4403, -4.59673, 3 ]
# Final position of art:  [ 3.08682, -2.77635, 2.73264 ]
# Goal position:  [ -10.339, -6.25533, 3 ]
# Distance to goal:  13.8718296230281
# Reward:  -248.71814846541167
# Accumulated Reward:  -1292.5528506480455
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj28.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 2.16807, 10.4987, 3 ]
# Goal position:  [ -5.20291, -10.0204, 3 ]
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj29.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 12.1247, -2.78226, 3 ]
# Goal position:  [ -10.1566, 2.66343, 2.5 ]
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj30.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 12.4659, -0.846029, 3 ]
# Goal position:  [ -10.3827, 1.56541, 2.5 ]
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj31.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.31976, -10.2405, 3 ]
# Final position of art:  [ 2.3108, -3.36401, 2.84908 ]
# Goal position:  [ -9.09653, 5.24434, 2.5 ]
# Distance to goal:  14.295199317511294
# Reward:  -252.95405545830212
# Accumulated Reward:  -1525.135625743406
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj32.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.9002, 5.57111, 3 ]
# Final position of art:  [ 10.6826, 5.45839, 2.30734 ]
# Goal position:  [ -9.68223, -4.06256, 2.5 ]
# Distance to goal:  22.481386793824285
# Reward:  -334.81177224127794
# Accumulated Reward:  -2194.831717601073
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj33.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.82041, 8.73915, 3 ]
# Final position of art:  [ 1.0199, -0.00688216, 2.69516 ]
# Goal position:  [ -4.13069, -9.65336, 2.5 ]
# Distance to goal:  10.937151993412991
# Reward:  -225.76927470766634
# Accumulated Reward:  -2043.1904917728089
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj34.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.74447, -9.36696, 3 ]
# Final position of art:  [ 6.53301, -9.08582, 2.3849 ]
# Goal position:  [ -4.06473, 7.87339, 3 ]
# Distance to goal:  20.00762689549796
# Reward:  -310.0768064227047
# Accumulated Reward:  -1225.7568000782412
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj35.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.0888, -6.69485, 3 ]
# Final position of art:  [ 2.63086, -1.42467, 2.77838 ]
# Goal position:  [ -8.32044, 2.22218, 3 ]
# Distance to goal:  11.544676121703244
# Reward:  -225.4439472503707
# Accumulated Reward:  -1172.582694600008
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj36.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.3208, -4.83456, 3 ]
# Final position of art:  [ 3.02421, -2.72816, 2.75369 ]
# Goal position:  [ -9.46462, -4.54653, 2.5 ]
# Distance to goal:  12.623065200418585
# Reward:  -236.23033668644956
# Accumulated Reward:  -1319.9031649436854
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj37.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.66621, -9.83915, 3 ]
# Final position of art:  [ 4.05515, -4.90316, 2.31423 ]
# Goal position:  [ -7.81564, 7.01183, 2.5 ]
# Distance to goal:  16.820148206992343
# Reward:  -278.006245584153
# Accumulated Reward:  -1542.0600843944521
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj38.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.87652, -9.75821, 3 ]
# Final position of art:  [ 4.7052, -4.33435, 2.39828 ]
# Goal position:  [ 1.06146, 10.4462, 2.5 ]
# Distance to goal:  15.223407227607531
# Reward:  -262.21899605241623
# Accumulated Reward:  -1497.0344870736415
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj39.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 7.08645, 9.18575, 3 ]
# Goal position:  [ -9.78179, -3.81663, 2.5 ]
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj40.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.76524, 10.1293, 3 ]
# Final position of art:  [ 1.78789, 1.69199, 2.23357 ]
# Goal position:  [ 6.13833, -9.82517, 3 ]
# Distance to goal:  12.335255213833141
# Reward:  -233.32987742568304
# Accumulated Reward:  -1212.5952152099408
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj41.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.33207, 7.51604, 3 ]
# Final position of art:  [ 2.00339, -0.606281, 2.88731 ]
# Goal position:  [ -0.491791, -10.4885, 2.5 ]
# Distance to goal:  10.19969195392736
# Reward:  -211.99721631288259
# Accumulated Reward:  -1188.5434940373752
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj42.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 4.9868, 10.0662, 3 ]
# Goal position:  [ -8.58841, -6.04063, 2.5 ]
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj43.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 12.4216, -1.28112, 3 ]
# Goal position:  [ -10.4984, 0.18373, 2.5 ]
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj44.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.6514, -4.13531, 3 ]
# Final position of art:  [ 2.94264, 0.691626, 2.16444 ]
# Goal position:  [ -8.38209, 6.3238, 2.5 ]
# Distance to goal:  12.652419234481137
# Reward:  -236.4788962725549
# Accumulated Reward:  -1011.3575901071904
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj45.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.05527, -10.4999, 3 ]
# Final position of art:  [ -1.3742, -3.89235, 2.2449 ]
# Goal position:  [ -9.44927, 6.06415, 3 ]
# Distance to goal:  12.841685532058191
# Reward:  -238.74555673167396
# Accumulated Reward:  -1294.7144360829443
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj46.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 3.12047, 10.44, 3 ]
# Final position of art:  [ 3.11737, 10.5175, 2.25828 ]
# Goal position:  [ -6.94594, -7.87425, 2.5 ]
# Distance to goal:  20.966258443996935
# Reward:  -319.6648808012076
# Accumulated Reward:  -2255.0277409943583
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj47.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.99148, 8.62277, 3 ]
# Final position of art:  [ 2.91171, 1.79875, 2.34171 ]
# Goal position:  [ -0.113082, -10.4994, 2.5 ]
# Distance to goal:  12.665649910743008
# Reward:  -236.66485021856977
# Accumulated Reward:  -863.6368439665985
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj48.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 3.25688, -10.4245, 3 ]
# Goal position:  [ 0.869015, 9.63902, 3 ]
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj49.png
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.83703, 6.98791, 3 ]
# Final position of art:  [ 3.23259, 1.55238, 2.26159 ]
# Goal position:  [ -5.22474, -9.10781, 2.5 ]
# Distance to goal:  13.609654029645512
# Reward:  -246.10306265668586
# Accumulated Reward:  -1406.6065348664351
# --------------------------------------------------------------
# Saved trajectory visualization to ./PLRTest_logs/TrajEval/iter102_level18Final/traj50.png
# Test Level level_5.bmp: Success rate = 0.38
#
# Mean Traversal Time: 7.49 s
# Average Roll/Pitch Angle: 7.19/5.29 deg
# Variance Roll/Pitch Angle: 34.26/25.90 deg
