# %% [markdown]
# Test Stage-based RL

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from gym_chrono.envs.wheeled.off_road_artACL import off_road_art
from gymnasium.utils.env_checker import check_env
import torch as th
import numpy as np
import os
import re
import matplotlib.pyplot as plt
import csv
from torch.utils.tensorboard import SummaryWriter

def evaluate_model(env, model, num_trials=50, max_steps=1000, render=False):
    success_count = 0
    traversal_times = []
    episode_roll_means = []
    episode_pitch_means = []

    for trial in range(num_trials):
        obs, _ = env.reset(seed=trial)
        if render:
            env.render('follow')
        
        step_count = 0
        roll_angles = []
        pitch_angles = []
        
        while step_count < max_steps:
            action, _states = model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, info = env.step(action)
            if render:
                env.render('follow')
            
            step_count += 1
            
            # Collect roll and pitch angles at each step
            euler_angles = env.m_vehicle.GetVehicle().GetRot().Q_to_Euler123()
            roll_angles.append(np.degrees(abs(euler_angles.x)))
            pitch_angles.append(np.degrees(abs(euler_angles.y)))
            
            if terminated or truncated:
                if terminated and step_count < 200:  # Successful trial
                    success_count += 1
                    traversal_times.append(env.m_system.GetChTime())
                break
        
        # Calculate mean roll and pitch angles for this episode
        episode_roll_means.append(np.mean(roll_angles))
        episode_pitch_means.append(np.mean(pitch_angles))

    mean_traversal_time = np.mean(traversal_times) if traversal_times else 0
    var_traversal_time = np.var(traversal_times) if traversal_times else 0
    avg_roll_angle = np.mean(episode_roll_means)
    var_roll_angle = np.var(episode_roll_means)
    avg_pitch_angle = np.mean(episode_pitch_means)
    var_pitch_angle = np.var(episode_pitch_means)

    return (success_count, mean_traversal_time, var_traversal_time, 
            avg_roll_angle, var_roll_angle, avg_pitch_angle, var_pitch_angle)

'''
calculates the success rate for level5, 
and returns the mean success rate.
'''
def evaluate_on_test_levels(env, model, test_level_dir, num_trials=50, max_steps=1000, render=False, writer=None, iteration=None):
    level_file = "level_5.bmp"
    level_path = os.path.join(test_level_dir, level_file)
    env.terrain_file = [level_path]
    env.update_terrain_stage(level_index=0)
    
    # Evaluate a single model on a given terrain
    (success_count, mean_traversal_time, var_traversal_time, 
     avg_roll_angle, var_roll_angle, avg_pitch_angle, var_pitch_angle) = evaluate_model(
        env, model, num_trials=num_trials, max_steps=max_steps, render=render)
    
    success_rate = float(success_count) / num_trials
    
    # Log the success rate for each test level
    if writer is not None and iteration is not None:
        writer.add_scalar(f'Success Rate/Test Level 5', success_rate, iteration)
    
    print(f"Test Level {level_file}: Success rate = {success_rate}\n")
    print(f"Mean Traversal Time: {mean_traversal_time:.2f} s", f"Average Roll/Pitch Angle: {avg_roll_angle:.2f}/{avg_pitch_angle:.2f} deg\n")
    print(f"Average Roll/Pitch Angle: {avg_roll_angle:.2f}/{avg_pitch_angle:.2f} deg")
    print(f"Variance Roll/Pitch Angle: {var_roll_angle:.2f}/{var_pitch_angle:.2f} deg\n")
    
    return (success_rate, mean_traversal_time, var_traversal_time, 
            avg_roll_angle, var_roll_angle, avg_pitch_angle, var_pitch_angle)

def extract_stage_and_iter(filename):
    """Extract stage and iteration numbers from the filename."""
    match = re.search(r'stage(\d+)_iter(\d+)', filename)
    if match:
        stage = int(match.group(1))
        iteration = int(match.group(2))
        return stage, iteration
    else:
        return None, None

# Loops through all the checkpoint files, evaluates each model on all test levels
def evaluate_checkpoints_on_test_levels(checkpoint_dir, test_level_dir, env, writer, csv_file, eval_interval=6, last_evaluated_iter=0):
    model_files = [f for f in os.listdir(checkpoint_dir) if f.endswith('.zip')]
    model_files = sorted(model_files, key=lambda f: extract_stage_and_iter(f))

    overall_success_rates = []
    iteration_numbers = []
    
    # Start the iteration counter at 0
    current_iteration = 0
    
    with open(csv_file, mode='w', newline='') as file:
        writer_csv = csv.writer(file)
        writer_csv.writerow(["Iteration", "Success Rate", "Mean Traversal Time", "Var Traversal Time", 
                             "Average Roll Angle", "Var Roll Angle", "Average Pitch Angle", "Var Pitch Angle"])
        
        for model_file in model_files:
            stage, iteration = extract_stage_and_iter(model_file)
            if (iteration - 1) % eval_interval != 0:
                continue
            
            print(f"Evaluating {model_file}")
            model = PPO.load(os.path.join(checkpoint_dir, model_file), env)
            
            (success_rate, mean_traversal_time, var_traversal_time, 
             avg_roll_angle, var_roll_angle, avg_pitch_angle, var_pitch_angle) = evaluate_on_test_levels(
                env, model, test_level_dir, num_trials=50, max_steps=1000, render=False, writer=writer, iteration=current_iteration)
            
            writer_csv.writerow([iteration, success_rate, mean_traversal_time, var_traversal_time, 
                                 avg_roll_angle, var_roll_angle, avg_pitch_angle, var_pitch_angle])
            
            overall_success_rates.append(success_rate)
            iteration_numbers.append(current_iteration)
            
            print(f"Checkpoint {model_file}: Success rate on last test level = {success_rate}\n")
            
            current_iteration += 5
    
    mean_success_rate = np.mean(overall_success_rates)
    print(f"Mean success rate across all evaluated checkpoints = {mean_success_rate}")
    
    return iteration_numbers, overall_success_rates, mean_success_rate

# Set up TensorBoard writer
checkpoint_dir = '../train/logs/vws_ppo_checkpoints_HopperNorm/'
test_level_dir = '../TestLevels'
last_evaluated_iter = 0

for run_index in range(1, 4):  # Run 3 evaluations
    log_dir = f'./StageTest_logs/run{run_index}'
    writer = SummaryWriter(log_dir)
    
    env = off_road_art()
    csv_file = f'./StageTest_logs/run{run_index}.csv'
    
    iteration_numbers, overall_success_rates, mean_success_rate = evaluate_checkpoints_on_test_levels(
        checkpoint_dir, test_level_dir, env, writer, csv_file, eval_interval=6, last_evaluated_iter=last_evaluated_iter)
    
    print(f"Overall success rates for all checkpoints in run {run_index}:", overall_success_rates)
    print(f"Mean success rate across all evaluated checkpoints in run {run_index}: {mean_success_rate}")
    
    writer.close()
# Out:
# Evaluating ppo_checkpoint_stage0_iter1.zip
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Terrain loaded from /home/tong/Documents/gym_chrono/envs/wheeled/../data/terrain_bitmaps/Automatic-CL/TrainLevels/../TestLevels/level_5.bmp
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.89368, -6.92386, 3 ]
# Final position of art:  [ 4.51501, -1.98017, 2.60062 ]
# Goal position:  [ -10.0442, 10.4854, 3 ]
# Distance to goal:  19.170817550701596
# Reward:  -301.7225196256779
# Accumulated Reward:  -1259.5771599877905
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.0744, 2.95918, 3 ]
# Final position of art:  [ 5.0211, -0.545161, 2.44286 ]
# Goal position:  [ -10.3566, 10.0123, 3 ]
# Distance to goal:  18.661307025979106
# Reward:  -296.52510902702136
# Accumulated Reward:  -1256.1804572594642
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.3542, 1.74385, 3 ]
# Final position of art:  [ 8.60336, 0.981922, 2.25095 ]
# Goal position:  [ -5.4422, -8.97956, 2.5 ]
# Distance to goal:  17.22123180152725
# Reward:  -282.1736177519289
# Accumulated Reward:  -1836.3539722486798
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.67012, -8.10923, 3 ]
# Final position of art:  [ 6.80924, -6.42101, 2.3003 ]
# Goal position:  [ -7.65241, 5.01568, 3 ]
# Distance to goal:  18.45065731888903
# Reward:  -294.50630217948174
# Accumulated Reward:  -2032.4821046831703
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.32683, 9.04848, 3 ]
# Final position of art:  [ 2.74634, -1.63562, 2.82391 ]
# Goal position:  [ -9.36126, -4.75571, 2.5 ]
# Distance to goal:  12.507357473162402
# Reward:  -235.07367663651075
# Accumulated Reward:  -1089.6099593681397
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.81412, -9.78276, 3 ]
# Final position of art:  [ 3.93487, -6.04564, 2.35915 ]
# Goal position:  [ -10.0888, 2.90961, 2.5 ]
# Distance to goal:  16.639713084499633
# Reward:  -268.03603326246576
# Accumulated Reward:  -644.467874599025
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.87561, 9.29938, 3 ]
# Final position of art:  [ 3.88344, 0.628306, 2.49134 ]
# Goal position:  [ -6.03138, -8.6085, 3 ]
# Distance to goal:  13.56027224535259
# Reward:  -245.61190936509206
# Accumulated Reward:  -1262.6222965587754
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.35846, -9.02978, 3 ]
# Final position of art:  [ 5.97028, -6.56116, 2.22902 ]
# Goal position:  [ -2.33541, 10.237, 2.5 ]
# Distance to goal:  18.74127596514611
# Reward:  -297.4114513208292
# Accumulated Reward:  -1538.27708196678
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.40824, 8.31772, 3 ]
# Final position of art:  [ 2.89043, -1.73934, 2.79318 ]
# Goal position:  [ -9.8376, -3.67037, 2.5 ]
# Distance to goal:  12.877017513486717
# Reward:  -238.73003655319926
# Accumulated Reward:  -1043.0560363128652
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.3551, -1.73852, 3 ]
# Final position of art:  [ 5.85433, -1.47871, 2.38934 ]
# Goal position:  [ -10.4796, 0.653442, 2.5 ]
# Distance to goal:  16.47291812219527
# Reward:  -274.7812632529251
# Accumulated Reward:  -932.6840228553953
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.0946, -2.88952, 3 ]
# Final position of art:  [ 4.06833, -0.969031, 2.54733 ]
# Goal position:  [ -9.1404, 5.16751, 2.5 ]
# Distance to goal:  14.564673998153477
# Reward:  -255.6623614382388
# Accumulated Reward:  -1140.519595675656
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.91579, -9.74251, 3 ]
# Final position of art:  [ 3.78947, -5.49007, 2.42298 ]
# Goal position:  [ -1.05727, 10.4466, 2.5 ]
# Distance to goal:  16.657588024268858
# Reward:  -276.5576180045807
# Accumulated Reward:  -1293.6656032911646
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4247, 1.25547, 3 ]
# Final position of art:  [ 2.76585, -1.5114, 2.81811 ]
# Goal position:  [ -8.73488, 6.56004, 3 ]
# Distance to goal:  14.051616189488092
# Reward:  -250.516132365655
# Accumulated Reward:  -1334.9427347234666
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.57167, 8.18921, 3 ]
# Final position of art:  [ 4.89981, 1.23563, 2.26273 ]
# Goal position:  [ 0.109906, -10.4994, 2.5 ]
# Distance to goal:  12.677180098102204
# Reward:  -236.73914570064068
# Accumulated Reward:  -1356.9376594196117
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.37741, -9.01851, 3 ]
# Final position of art:  [ 6.55095, -7.72439, 2.31852 ]
# Goal position:  [ -2.57888, 10.1784, 2.5 ]
# Distance to goal:  20.09716092857263
# Reward:  -294.73996665277235
# Accumulated Reward:  -1060.5454384659854
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.5838, 4.28965, 3 ]
# Final position of art:  [ 2.40983, -1.57029, 2.889 ]
# Goal position:  [ -4.68678, -9.39596, 2.5 ]
# Distance to goal:  10.571390523746942
# Reward:  -215.7140912158678
# Accumulated Reward:  -1113.329871705938
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.85732, -6.96509, 3 ]
# Final position of art:  [ 2.48001, 0.0652645, 2.37798 ]
# Goal position:  [ -6.57, 8.19055, 2.5 ]
# Distance to goal:  12.162967674532311
# Reward:  -222.87956992684195
# Accumulated Reward:  -435.7263794109001
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.55906, -8.90769, 3 ]
# Final position of art:  [ 7.44992, -8.60481, 2.26796 ]
# Goal position:  [ -10.3495, 1.77115, 2.5 ]
# Distance to goal:  20.604251665102776
# Reward:  -316.0393653099474
# Accumulated Reward:  -2215.5905182829574
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.82536, -7.979, 3 ]
# Final position of art:  [ -0.132913, -4.35246, 2.33653 ]
# Goal position:  [ -10.3358, -1.84941, 2.5 ]
# Distance to goal:  10.506749907967846
# Reward:  -215.0751881215
# Accumulated Reward:  -636.2730870395801
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 4.4268, -10.2157, 3 ]
# Goal position:  [ -6.05983, 8.57487, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.1971, -2.50381, 3 ]
# Final position of art:  [ 6.01307, -1.79447, 2.38608 ]
# Goal position:  [ -10.4291, -1.21824, 2.5 ]
# Distance to goal:  16.452645310949627
# Reward:  -274.5180370229916
# Accumulated Reward:  -1326.2065639416764
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.9381, 9.26634, 3 ]
# Final position of art:  [ 3.50447, -0.133023, 2.45926 ]
# Goal position:  [ -7.15618, -7.68369, 2.5 ]
# Distance to goal:  13.063833930727956
# Reward:  -240.34748623480687
# Accumulated Reward:  -1223.486663248989
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.7638, -5.78321, 3 ]
# Final position of art:  [ 8.82545, -4.77024, 2.30775 ]
# Goal position:  [ -9.89199, 3.52115, 2.5 ]
# Distance to goal:  20.472583665966933
# Reward:  -314.74293963703224
# Accumulated Reward:  -1997.8411385485201
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.96132, 9.25394, 3 ]
# Final position of art:  [ 2.81268, -1.6287, 2.80825 ]
# Goal position:  [ -8.49242, -7.14469, 3 ]
# Distance to goal:  12.580468038254429
# Reward:  -235.7953168318429
# Accumulated Reward:  -1080.8248527012859
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.66608, -7.17504, 3 ]
# Final position of art:  [ 3.15869, -2.33749, 2.71455 ]
# Goal position:  [ -10.4657, 0.848242, 2.5 ]
# Distance to goal:  13.99351131506691
# Reward:  -249.93674595566446
# Accumulated Reward:  -1348.04838168962
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.3238, 4.82866, 3 ]
# Final position of art:  [ 11.4066, 5.02739, 2.47486 ]
# Goal position:  [ -5.06567, -9.19723, 2.5 ]
# Distance to goal:  21.764115050041546
# Reward:  -327.63713285542383
# Accumulated Reward:  -1329.3895794342864
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.0224, 5.37093, 3 ]
# Final position of art:  [ 10.6491, 5.40647, 2.38841 ]
# Goal position:  [ -10.1188, -6.68593, 3 ]
# Distance to goal:  24.039622646097058
# Reward:  -350.0551060297267
# Accumulated Reward:  -1807.9125863937863
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.3537, -6.36125, 3 ]
# Final position of art:  [ 10.3779, -6.54917, 2.44 ]
# Goal position:  [ -9.62441, 5.38327, 3 ]
# Distance to goal:  23.297813379653757
# Reward:  -342.9799765171775
# Accumulated Reward:  -2271.8748768384876
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.757, 3.87955, 3 ]
# Final position of art:  [ 10.2864, 3.33023, 2.28796 ]
# Goal position:  [ -9.99398, -3.22032, 2.5 ]
# Distance to goal:  21.31308738929382
# Reward:  -322.9905675902064
# Accumulated Reward:  -1826.8621922506982
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.879, 3.5575, 3 ]
# Final position of art:  [ 5.54254, 0.376802, 2.19304 ]
# Goal position:  [ -10.275, -2.16181, 2.5 ]
# Distance to goal:  16.022945050170872
# Reward:  -270.21730875044284
# Accumulated Reward:  -1429.5773119584942
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.167, 2.62352, 3 ]
# Final position of art:  [ 5.54373, 0.367209, 2.19542 ]
# Goal position:  [ -7.5283, 7.31948, 2.5 ]
# Distance to goal:  14.808941217122063
# Reward:  -258.08725962035464
# Accumulated Reward:  -1488.0117530845475
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.17284, -9.63522, 3 ]
# Final position of art:  [ 3.3271, -5.02736, 2.47798 ]
# Goal position:  [ -0.223352, 10.0534, 3 ]
# Distance to goal:  15.501810573371651
# Reward:  -264.9809525887526
# Accumulated Reward:  -1617.730287822996
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.7991, -5.72939, 3 ]
# Final position of art:  [ 8.83519, -4.77927, 2.33355 ]
# Goal position:  [ -7.54239, 3.04713, 3 ]
# Distance to goal:  18.16374823752811
# Reward:  -291.63742892411267
# Accumulated Reward:  -1875.8869461443587
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.1677, -2.6208, 3 ]
# Final position of art:  [ 4.04269, -0.886069, 2.52825 ]
# Goal position:  [ -8.90973, -5.55578, 2.5 ]
# Distance to goal:  13.768521667535843
# Reward:  -247.68426656752433
# Accumulated Reward:  -1164.0624051657417
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 3.45139, 10.3992, 3 ]
# Final position of art:  [ 4.03707, -3.36489, 2.32942 ]
# Goal position:  [ -8.16092, -6.60677, 2.5 ]
# Distance to goal:  12.62259099859921
# Reward:  -236.2274985774605
# Accumulated Reward:  -1089.3497738142598
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.5548, -4.35394, 3 ]
# Final position of art:  [ 5.1347, -1.67796, 2.61657 ]
# Goal position:  [ -7.03275, 7.79682, 2.5 ]
# Distance to goal:  15.421800634083427
# Reward:  -252.86993366644106
# Accumulated Reward:  -925.8208842957846
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4999, 0.0470341, 3 ]
# Final position of art:  [ 2.74777, -1.53131, 2.82541 ]
# Goal position:  [ -7.42876, 6.48149, 3 ]
# Distance to goal:  12.953661692143497
# Reward:  -239.53868628448697
# Accumulated Reward:  -1152.7440880910628
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.2282, -2.37364, 3 ]
# Final position of art:  [ 4.8252, -1.04782, 2.5032 ]
# Goal position:  [ -10.1026, 2.86139, 2.5 ]
# Distance to goal:  15.431169337182554
# Reward:  -264.32909417370604
# Accumulated Reward:  -1071.3220182597179
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.2739, -2.16745, 3 ]
# Final position of art:  [ 5.80942, -1.49133, 2.39706 ]
# Goal position:  [ -10.4648, -0.859566, 2.5 ]
# Distance to goal:  16.286759585664935
# Reward:  -273.2076102914292
# Accumulated Reward:  -1190.9447393468834
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.31479, 9.57249, 3 ]
# Final position of art:  [ 4.51312, 1.52874, 2.2772 ]
# Goal position:  [ -9.83564, -3.67562, 2.5 ]
# Distance to goal:  15.265060521772789
# Reward:  -262.56387461443114
# Accumulated Reward:  -1533.2667593516078
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 3.92827, 10.3214, 3 ]
# Final position of art:  [ 3.88611, 9.9911, 2.34336 ]
# Goal position:  [ -0.712235, -10.4758, 2.5 ]
# Distance to goal:  20.977705668084056
# Reward:  -319.77742219800746
# Accumulated Reward:  -2215.4296324863712
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.87307, 8.70385, 3 ]
# Final position of art:  [ 2.5791, -1.48704, 2.83563 ]
# Goal position:  [ -4.38735, -9.53945, 2.5 ]
# Distance to goal:  10.652946930868106
# Reward:  -216.52940948180614
# Accumulated Reward:  -1022.3793767008086
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.69968, 8.81837, 3 ]
# Final position of art:  [ 3.46089, -0.398291, 2.59399 ]
# Goal position:  [ -4.93189, -8.23121, 3 ]
# Distance to goal:  11.487306146619003
# Reward:  -224.82143786370526
# Accumulated Reward:  -1170.9787797092827
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.78734, 8.01137, 3 ]
# Final position of art:  [ 4.00566, 0.738434, 2.5013 ]
# Goal position:  [ -10.1463, -2.70218, 2.5 ]
# Distance to goal:  14.564239338556346
# Reward:  -255.6082851723452
# Accumulated Reward:  -1448.1297367105813
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.66304, -9.84033, 3 ]
# Final position of art:  [ 2.76215, -3.04014, 2.8054 ]
# Goal position:  [ -10.0927, 2.8961, 2.5 ]
# Distance to goal:  14.162602143447348
# Reward:  -251.62602251139168
# Accumulated Reward:  -1468.5451540233553
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.83686, 10.4666, 3 ]
# Final position of art:  [ 12.3893, -12.2248, 2.63595 ]
# Goal position:  [ -4.82482, -9.32583, 2.5 ]
# Distance to goal:  17.457082422935123
# Reward:  -284.56268584097097
# Accumulated Reward:  -808.3193995213089
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.5422, 6.1058, 3 ]
# Final position of art:  [ 5.16044, 0.666325, 2.28296 ]
# Goal position:  [ -9.04525, -5.33231, 2.5 ]
# Distance to goal:  15.421811548355654
# Reward:  -264.4486209989618
# Accumulated Reward:  -1043.6378455248587
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.8679, -3.58802, 3 ]
# Final position of art:  [ 4.51803, -2.88474, 2.75692 ]
# Goal position:  [ -10.4983, 0.189128, 2.5 ]
# Distance to goal:  15.329861058040587
# Reward:  -263.13025590334655
# Accumulated Reward:  -1317.6694627058944
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.21879, 9.99447, 3 ]
# Final position of art:  [ 1.30984, 1.92173, 2.45341 ]
# Goal position:  [ 3.9012, -10.3454, 3 ]
# Distance to goal:  12.549781470732968
# Reward:  -235.47445103051035
# Accumulated Reward:  -1336.496337754076
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.937, 3.39203, 3 ]
# Final position of art:  [ 3.97504, -1.36339, 2.57654 ]
# Goal position:  [ -6.74531, -8.83191, 3 ]
# Distance to goal:  13.072262352303065
# Reward:  -240.7229718976032
# Accumulated Reward:  -1090.6937999884724
# --------------------------------------------------------------
# Test Level level_5.bmp: Success rate = 0.02
#
# Mean Traversal Time: 10.90 s Average Roll/Pitch Angle: 7.69/6.05 deg
#
# Average Roll/Pitch Angle: 7.69/6.05 deg
# Variance Roll/Pitch Angle: 19.79/18.54 deg
#
# Checkpoint ppo_checkpoint_stage0_iter1.zip: Success rate on last test level = 0.02
#
# Evaluating ppo_checkpoint_stage0_iter7.zip
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Terrain loaded from /home/tong/Documents/gym_chrono/envs/wheeled/../data/terrain_bitmaps/Automatic-CL/TrainLevels/../TestLevels/level_5.bmp
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.53244, -8.22053, 3 ]
# Final position of art:  [ 6.30612, -5.59834, 2.36203 ]
# Goal position:  [ -4.95384, 8.95228, 3 ]
# Distance to goal:  18.409618136554556
# Reward:  -294.0960065922839
# Accumulated Reward:  -1935.554211288719
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 12.1472, -2.69904, 3 ]
# Goal position:  [ -10.4969, 4.45425, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.04506, 10.2989, 3 ]
# Final position of art:  [ 1.84612, 1.70362, 2.22595 ]
# Goal position:  [ 3.43186, -9.92332, 2.5 ]
# Distance to goal:  11.737775950792205
# Reward:  -227.51356263850317
# Accumulated Reward:  -1314.9573200994955
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 9.07913, -7.75473, 3 ]
# Goal position:  [ -6.18754, 8.48318, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.6336, -5.97585, 3 ]
# Final position of art:  [ 3.04931, -2.81313, 2.72221 ]
# Goal position:  [ -9.92266, -4.51008, 3 ]
# Distance to goal:  13.085437360723686
# Reward:  -240.85441859422113
# Accumulated Reward:  -1297.0569529302763
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 5.65106, 9.84478, 3 ]
# Goal position:  [ -8.92748, -5.52721, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 8.7196, 8.06827, 3 ]
# Goal position:  [ -9.54166, -9.58225, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.35913, -7.48954, 3 ]
# Final position of art:  [ 5.19601, -3.44521, 2.51107 ]
# Goal position:  [ -7.09541, 6.95954, 3 ]
# Distance to goal:  16.11138531597202
# Reward:  -270.9626194908633
# Accumulated Reward:  -1464.3664456048211
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.2663, -2.20293, 3 ]
# Final position of art:  [ 2.72867, 0.832744, 2.22616 ]
# Goal position:  [ -10.4922, 0.403751, 2.5 ]
# Distance to goal:  13.23069891706698
# Reward:  -242.31803634220398
# Accumulated Reward:  -1060.7168389729527
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.36876, -7.48007, 3 ]
# Final position of art:  [ 3.85471, -0.711069, 2.45877 ]
# Goal position:  [ -2.99296, 10.0644, 2.5 ]
# Distance to goal:  12.767266031600618
# Reward:  -237.67269081816227
# Accumulated Reward:  -1365.1012719315972
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.14943, -9.15059, 3 ]
# Final position of art:  [ 4.75577, -4.70431, 2.31172 ]
# Goal position:  [ -6.79569, 5.30557, 3 ]
# Distance to goal:  15.300574029042446
# Reward:  -263.01015204263564
# Accumulated Reward:  -1296.3921100996488
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.67877, -10.478, 3 ]
# Final position of art:  [ 2.87932, -10.1628, 2.61011 ]
# Goal position:  [ -9.16997, 6.84453, 3 ]
# Distance to goal:  20.84676451561229
# Reward:  -318.46698973652644
# Accumulated Reward:  -2253.7965406107965
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.83, 3.69069, 3 ]
# Final position of art:  [ -0.372741, 0.331158, 2.38177 ]
# Goal position:  [ -6.10791, -8.54069, 2.5 ]
# Distance to goal:  10.564842084226873
# Reward:  -215.61689650957027
# Accumulated Reward:  -938.9588812069694
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 4.75804, -10.1313, 3 ]
# Goal position:  [ 2.369, 10.2293, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 12.4692, 0.803332, 3 ]
# Goal position:  [ -10.4566, 0.953383, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.1261, -5.19268, 3 ]
# Final position of art:  [ 5.87233, -2.25598, 2.39346 ]
# Goal position:  [ -8.69192, 5.89071, 2.5 ]
# Distance to goal:  16.688235581327014
# Reward:  -277.2254340427336
# Accumulated Reward:  -1488.5387795055735
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.6857, -5.89981, 3 ]
# Final position of art:  [ 5.63604, -2.86008, 2.37183 ]
# Goal position:  [ -10.0041, 3.18866, 2.5 ]
# Distance to goal:  16.769564764967328
# Reward:  -277.69708091650557
# Accumulated Reward:  -1328.4633572639023
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 12.0883, 2.91156, 3 ]
# Goal position:  [ -10.2407, 2.31926, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 9.46582, -7.38319, 3 ]
# Goal position:  [ -4.49829, 9.48764, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.25602, -7.58947, 3 ]
# Final position of art:  [ 5.20494, -3.44142, 2.503 ]
# Goal position:  [ -7.34059, 7.50771, 2.5 ]
# Distance to goal:  16.651537105329126
# Reward:  -276.53449895173634
# Accumulated Reward:  -1599.5384354544733
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 5.96815, 9.72131, 3 ]
# Goal position:  [ -7.74479, -7.09, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.42531, -9.5219, 3 ]
# Final position of art:  [ 3.3543, -5.3053, 2.44601 ]
# Goal position:  [ -8.72219, 5.8458, 2.5 ]
# Distance to goal:  16.43750631121668
# Reward:  -274.37379228052976
# Accumulated Reward:  -1259.391761839242
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.09753, 9.17961, 3 ]
# Final position of art:  [ 2.21221, 1.94617, 2.25611 ]
# Goal position:  [ -4.11238, -9.66118, 2.5 ]
# Distance to goal:  13.220834090892758
# Reward:  -231.58266982071277
# Accumulated Reward:  -608.6700898911854
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 6.72426, 9.37717, 3 ]
# Goal position:  [ -10.3504, -4.09645, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.93266, 10.0821, 3 ]
# Final position of art:  [ 3.46463, -3.25446, 2.38074 ]
# Goal position:  [ 8.05923, -9.92085, 3 ]
# Distance to goal:  8.120016584606969
# Reward:  -191.4277956422817
# Accumulated Reward:  -912.6770935904555
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.78463, 7.04624, 3 ]
# Final position of art:  [ 8.20891, 5.9207, 2.29207 ]
# Goal position:  [ -9.89865, 2.25756, 3 ]
# Distance to goal:  18.487922493288256
# Reward:  -294.87610595838345
# Accumulated Reward:  -2078.8057293987745
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.5797, -10.1782, 3 ]
# Final position of art:  [ 4.41152, -4.04517, 2.36778 ]
# Goal position:  [ -1.90522, 10.2034, 3 ]
# Distance to goal:  15.598772090163177
# Reward:  -265.98773063445435
# Accumulated Reward:  -1419.2510606128117
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.0605, -3.00608, 3 ]
# Final position of art:  [ 4.03432, -0.898823, 2.53832 ]
# Goal position:  [ -10.3179, -4.73631, 3 ]
# Distance to goal:  14.863616004516366
# Reward:  -258.6365517090122
# Accumulated Reward:  -1332.1179236874673
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.17375, 10.4986, 3 ]
# Final position of art:  [ 4.75048, -2.4574, 2.46454 ]
# Goal position:  [ 9.89431, -8.99799, 3 ]
# Distance to goal:  8.338168098783884
# Reward:  -193.38073296737065
# Accumulated Reward:  -714.342242426756
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 3.60372, -10.3768, 3 ]
# Final position of art:  [ 2.89742, -3.07526, 2.72869 ]
# Goal position:  [ -5.96121, 9.81103, 3 ]
# Distance to goal:  15.63985549033382
# Reward:  -266.39814519720926
# Accumulated Reward:  -1457.3799909059903
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.4602, 4.55565, 3 ]
# Final position of art:  [ 1.06886, -0.134882, 2.69418 ]
# Goal position:  [ -5.35058, -9.03445, 2.5 ]
# Distance to goal:  10.974934810574956
# Reward:  -233.0937593060889
# Accumulated Reward:  -2420.2021905198367
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 11.8233, 3.70836, 3 ]
# Goal position:  [ -9.06415, 5.30011, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 12.4158, 1.32711, 3 ]
# Goal position:  [ -10.2125, 2.44026, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.59181, 10.1751, 3 ]
# Final position of art:  [ 4.41167, 9.96821, 2.39473 ]
# Goal position:  [ -6.65756, -8.11953, 2.5 ]
# Distance to goal:  21.206263140006516
# Reward:  -322.05848696705664
# Accumulated Reward:  -2240.6245134298524
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4894, -0.472067, 3 ]
# Final position of art:  [ 2.32832, -2.72807, 3.05603 ]
# Goal position:  [ -6.49252, -8.2521, 2.5 ]
# Distance to goal:  10.422639723767547
# Reward:  -203.47891407051537
# Accumulated Reward:  -1030.8086036079458
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.1908, 2.52931, 3 ]
# Final position of art:  [ 2.63976, -1.92178, 2.92377 ]
# Goal position:  [ -5.05525, -9.20296, 2.5 ]
# Distance to goal:  10.602279137754651
# Reward:  -216.022962230507
# Accumulated Reward:  -1175.2322031767399
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 12.4311, -1.2012, 3 ]
# Goal position:  [ -7.20178, 7.64097, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.8431, -10.1078, 3 ]
# Final position of art:  [ 3.46426, -4.56575, 2.57807 ]
# Goal position:  [ -8.57248, 6.06322, 2.5 ]
# Distance to goal:  16.058148900659635
# Reward:  -270.55657339712684
# Accumulated Reward:  -1728.1538331239913
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.53994, -10.1882, 3 ]
# Final position of art:  [ 4.40753, -4.04929, 2.36681 ]
# Goal position:  [ -0.833214, 9.8243, 3 ]
# Distance to goal:  14.843949962275323
# Reward:  -258.44281877680413
# Accumulated Reward:  -1437.323432405188
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 3.82714, -10.3398, 3 ]
# Final position of art:  [ 3.69287, -0.543981, 2.42633 ]
# Goal position:  [ -2.29624, 8.9782, 3 ]
# Distance to goal:  11.26368096809085
# Reward:  -222.64073682806193
# Accumulated Reward:  -1059.1397129954853
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.317, 4.84193, 3 ]
# Final position of art:  [ 6.15214, 2.74752, 2.17305 ]
# Goal position:  [ -8.90863, -3.21014, 3 ]
# Distance to goal:  16.217405701498567
# Reward:  -247.20031572778782
# Accumulated Reward:  -272.3302261506748
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 12.3583, -1.71912, 3 ]
# Goal position:  [ -4.57078, 9.99774, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.0241, -3.12534, 3 ]
# Final position of art:  [ 4.72313, -0.959782, 2.51017 ]
# Goal position:  [ -8.78312, -5.75385, 2.5 ]
# Distance to goal:  14.331854779301233
# Reward:  -253.30222111955095
# Accumulated Reward:  -1093.2060274802338
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 5.4938, 9.90168, 3 ]
# Goal position:  [ -7.73012, -7.106, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.7486, -5.8062, 3 ]
# Final position of art:  [ 5.67204, -2.72328, 2.38658 ]
# Goal position:  [ -10.357, 5.396, 3 ]
# Distance to goal:  17.978603203159473
# Reward:  -289.80939933310896
# Accumulated Reward:  -1286.7640127382454
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 11.5456, 4.37395, 3 ]
# Goal position:  [ -9.74561, -3.90808, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.26, -4.94997, 3 ]
# Final position of art:  [ 4.75657, -2.64225, 2.76936 ]
# Goal position:  [ -9.47108, -4.53305, 2.5 ]
# Distance to goal:  14.35527138081114
# Reward:  -253.5514074544074
# Accumulated Reward:  -1396.4309486929621
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4742, -0.734913, 3 ]
# Final position of art:  [ 2.2806, -0.430372, 2.81896 ]
# Goal position:  [ -7.98585, -6.81735, 2.5 ]
# Distance to goal:  12.095254815872705
# Reward:  -230.95123413603363
# Accumulated Reward:  -1020.4853569460226
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 3.9294, 10.3212, 3 ]
# Final position of art:  [ 3.64891, 10.1127, 2.33246 ]
# Goal position:  [ -2.88022, -9.3571, 3 ]
# Distance to goal:  20.54622889390969
# Reward:  -315.4631262071212
# Accumulated Reward:  -2244.3275785941682
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.3415, -4.79442, 3 ]
# Final position of art:  [ 5.76296, -2.50908, 2.39007 ]
# Goal position:  [ -8.64926, -1.11241, 3 ]
# Distance to goal:  14.492578153534213
# Reward:  -254.78609667163988
# Accumulated Reward:  -1285.6894700181756
# --------------------------------------------------------------
# Test Level level_5.bmp: Success rate = 0.32
#
# Mean Traversal Time: 8.62 s Average Roll/Pitch Angle: 8.77/4.45 deg
#
# Average Roll/Pitch Angle: 8.77/4.45 deg
# Variance Roll/Pitch Angle: 53.08/13.82 deg
#
# Checkpoint ppo_checkpoint_stage0_iter7.zip: Success rate on last test level = 0.32
#
# Evaluating ppo_checkpoint_stage1_iter1.zip
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Terrain loaded from /home/tong/Documents/gym_chrono/envs/wheeled/../data/terrain_bitmaps/Automatic-CL/TrainLevels/../TestLevels/level_5.bmp
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.49036, 9.4914, 3 ]
# Final position of art:  [ -12.3757, -6.10186, 2.1578 ]
# Goal position:  [ -10.4261, -1.24323, 2.5 ]
# Distance to goal:  5.246368163810427
# Reward:  -162.45617718717386
# Accumulated Reward:  -287.26844341586997
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4612, -0.901644, 3 ]
# Final position of art:  [ 5.71131, -1.0899, 2.69908 ]
# Goal position:  [ -10.3615, -5.68377, 3 ]
# Distance to goal:  16.719155456069576
# Reward:  -261.4453907757918
# Accumulated Reward:  -1234.1168153269198
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.43352, 8.98481, 3 ]
# Final position of art:  [ 4.52741, 0.527931, 2.42574 ]
# Goal position:  [ 0.873862, -10.4636, 2.5 ]
# Distance to goal:  11.583052713022338
# Reward:  -225.82041975770125
# Accumulated Reward:  -1350.8438714393583
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.00666, 10.3065, 3 ]
# Final position of art:  [ 4.59181, 1.32185, 2.3099 ]
# Goal position:  [ -5.60135, -9.97111, 3 ]
# Distance to goal:  15.228513668550994
# Reward:  -243.10086749039436
# Accumulated Reward:  -1395.2549380198218
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4849, 0.563592, 3 ]
# Final position of art:  [ 4.67244, -1.95645, 2.61817 ]
# Goal position:  [ -10.1623, -2.64145, 2.5 ]
# Distance to goal:  14.851033449035892
# Reward:  -258.50940410240486
# Accumulated Reward:  -1379.651198614296
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.1483, -5.15353, 3 ]
# Final position of art:  [ 4.25354, -4.02694, 2.69343 ]
# Goal position:  [ -9.62734, 4.19098, 2.5 ]
# Distance to goal:  16.132276222249036
# Reward:  -271.31733555017047
# Accumulated Reward:  -1431.140701273926
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.71244, -9.8218, 3 ]
# Final position of art:  [ 3.24241, -5.05957, 2.45743 ]
# Goal position:  [ -8.36947, 6.3405, 2.5 ]
# Distance to goal:  16.2726536256209
# Reward:  -272.65780320067284
# Accumulated Reward:  -1606.4997985773891
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.5049, -6.15767, 3 ]
# Final position of art:  [ 2.92055, -2.76025, 2.7717 ]
# Goal position:  [ -7.3798, 7.46917, 2.5 ]
# Distance to goal:  14.519369173703833
# Reward:  -255.19391614899445
# Accumulated Reward:  -1439.1698636012277
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# ...
# --------------------------------------------------------------
# Time out
# Initial position:  [ 3.62401, -10.3736, 3 ]
# Final position of art:  [ 2.99984, -3.01457, 2.70218 ]
# Goal position:  [ -8.2069, 6.54957, 2.5 ]
# Distance to goal:  14.734469624802342
# Reward:  -257.3439266016098
# Accumulated Reward:  -1479.6132761271344
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.59283, 10.1748, 3 ]
# Final position of art:  [ 1.6458, 1.95223, 2.21497 ]
# Goal position:  [ -2.28995, -9.93938, 3 ]
# Distance to goal:  12.55056718354108
# Reward:  -235.58678536785828
# Accumulated Reward:  -1302.8920696300736
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.53791, 7.30958, 3 ]
# Final position of art:  [ 3.77851, -1.73324, 2.60926 ]
# Goal position:  [ -8.62629, -5.98641, 2.5 ]
# Distance to goal:  13.114126250961124
# Reward:  -248.0309796157083
# Accumulated Reward:  -1564.8350710223363
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.0549, -3.02488, 3 ]
# Final position of art:  [ 1.65754, 0.132378, 2.5849 ]
# Goal position:  [ -4.2232, 9.61325, 2.5 ]
# Distance to goal:  11.156935755918013
# Reward:  -221.60476456679328
# Accumulated Reward:  -1121.37938033513
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.7761, -3.83116, 3 ]
# Final position of art:  [ 5.36758, -1.80634, 2.46969 ]
# Goal position:  [ -9.93715, -3.39161, 2.5 ]
# Distance to goal:  15.38664272820323
# Reward:  -263.8515468385326
# Accumulated Reward:  -1479.3387047454746
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.9356, 3.39607, 3 ]
# Final position of art:  [ -6.93529, 1.13004, 2.19387 ]
# Goal position:  [ -8.38581, 6.52591, 3 ]
# Distance to goal:  5.645291282261713
# Reward:  -166.53040812154703
# Accumulated Reward:  -503.16698303876444
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 2.6904, 10.4773, 3 ]
# Goal position:  [ 8.61809, -8.88634, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.7126, 3.98948, 3 ]
# Final position of art:  [ -12.2672, -3.32268, 2.21097 ]
# Goal position:  [ -10.0562, 1.61263, 3 ]
# Distance to goal:  5.465171450267553
# Reward:  -164.90979337575848
# Accumulated Reward:  -136.0194265475329
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.8728, -3.57449, 3 ]
# Final position of art:  [ 5.37918, -1.9991, 2.46913 ]
# Goal position:  [ -8.85917, 5.63605, 2.5 ]
# Distance to goal:  16.156335292445227
# Reward:  -271.61139036016414
# Accumulated Reward:  -1447.364229137037
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 5.19968, 10.0006, 3 ]
# Goal position:  [ -9.75399, -3.88712, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 11.8614, 3.60582, 3 ]
# Goal position:  [ -9.22143, 8.90381, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.82837, 6.99762, 3 ]
# Final position of art:  [ 4.03481, 0.597992, 2.47905 ]
# Goal position:  [ -5.87055, -6.86985, 3 ]
# Distance to goal:  12.415966572261228
# Reward:  -234.39198353726164
# Accumulated Reward:  -1280.6027573428585
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4264, -1.24076, 3 ]
# Final position of art:  [ 5.87526, -1.50438, 2.37771 ]
# Goal position:  [ -10.4987, 0.164997, 2.5 ]
# Distance to goal:  16.459300475247012
# Reward:  -274.8212027021391
# Accumulated Reward:  -601.6172491170003
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.271, 6.46839, 3 ]
# Final position of art:  [ 4.081, -0.903762, 2.49968 ]
# Goal position:  [ -5.66848, -9.6946, 3 ]
# Distance to goal:  13.137032273693318
# Reward:  -241.37800216334608
# Accumulated Reward:  -1106.501841053438
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.81179, 9.33256, 3 ]
# Final position of art:  [ 2.27887, 1.52819, 2.47303 ]
# Goal position:  [ -8.54325, -6.10433, 2.5 ]
# Distance to goal:  13.242896458046973
# Reward:  -242.17654974213684
# Accumulated Reward:  -777.74236575033
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.08265, -8.5587, 3 ]
# Final position of art:  [ 6.78546, -6.54736, 2.2957 ]
# Goal position:  [ -8.63953, 5.96728, 2.5 ]
# Distance to goal:  19.864250964300762
# Reward:  -308.64385765209033
# Accumulated Reward:  -1966.4877115286831
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.9319, 5.52002, 3 ]
# Final position of art:  [ 10.568, 5.41633, 2.34353 ]
# Goal position:  [ -6.41478, -8.31267, 2.5 ]
# Distance to goal:  21.838626434650028
# Reward:  -328.38649119477395
# Accumulated Reward:  -2103.1861199878476
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.9466, -3.3637, 3 ]
# Final position of art:  [ 3.0769, -2.69817, 2.72771 ]
# Goal position:  [ -10.3427, -0.263919, 3 ]
# Distance to goal:  13.641358388905473
# Reward:  -246.41368209786143
# Accumulated Reward:  -1345.9872134842553
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.0442, 5.33415, 3 ]
# Final position of art:  [ 10.8675, 5.4232, 2.35451 ]
# Goal position:  [ -9.58284, -7.43165, 3 ]
# Distance to goal:  24.163605321184722
# Reward:  -351.6638125836779
# Accumulated Reward:  -2059.7087665103204
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.4917, -6.17589, 3 ]
# Final position of art:  [ 5.37418, -3.13022, 2.33627 ]
# Goal position:  [ -7.62456, 8.38507, 3 ]
# Distance to goal:  17.378427022033723
# Reward:  -283.73405073031864
# Accumulated Reward:  -1613.272417075338
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.77368, -8.02292, 3 ]
# Final position of art:  [ 6.52736, -6.29917, 2.32969 ]
# Goal position:  [ -6.37894, 8.34021, 2.5 ]
# Distance to goal:  19.51699383671951
# Reward:  -305.17037764666884
# Accumulated Reward:  -1998.1741990990524
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 3.28108, 10.4216, 3 ]
# Final position of art:  [ 3.47446, -3.24398, 2.38174 ]
# Goal position:  [ -3.83919, -9.77295, 2.5 ]
# Distance to goal:  9.80464411380611
# Reward:  -208.04260081441123
# Accumulated Reward:  -818.6135113124678
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.1437, 5.16171, 3 ]
# Final position of art:  [ 11.2042, 5.4083, 2.32969 ]
# Goal position:  [ -3.241, -9.98729, 2.5 ]
# Distance to goal:  21.112023123420972
# Reward:  -321.1189357745699
# Accumulated Reward:  -1964.2644968111204
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.9576, -3.33124, 3 ]
# Final position of art:  [ 5.38828, -1.997, 2.45694 ]
# Goal position:  [ -8.55532, 9.58523, 3 ]
# Distance to goal:  18.13468707951683
# Reward:  -291.25299642371465
# Accumulated Reward:  -1598.6241118284918
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.6697, 7.17117, 3 ]
# Final position of art:  [ 4.03408, 0.618091, 2.47751 ]
# Goal position:  [ -7.41798, -7.43125, 2.5 ]
# Distance to goal:  13.997934641300846
# Reward:  -249.67114310723343
# Accumulated Reward:  -1297.9436958677652
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.09609, 9.66809, 3 ]
# Final position of art:  [ -12.2165, -10.8339, 2.52683 ]
# Goal position:  [ -9.70462, -4.00878, 2.5 ]
# Distance to goal:  7.272729045538405
# Reward:  -182.681314307678
# Accumulated Reward:  -76.59197662191981
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.10161, -9.66576, 3 ]
# Final position of art:  [ 2.81397, -2.95674, 2.79877 ]
# Goal position:  [ -6.78387, 8.0143, 2.5 ]
# Distance to goal:  14.579836877902052
# Reward:  -255.7985135447593
# Accumulated Reward:  -1503.065811815795
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.13164, -9.16058, 3 ]
# Final position of art:  [ 7.14166, -8.99994, 2.42186 ]
# Goal position:  [ -9.838, 2.18492, 3 ]
# Distance to goal:  20.34070213904979
# Reward:  -313.3469088892826
# Accumulated Reward:  -2022.1727864200623
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.82751, 9.77753, 3 ]
# Final position of art:  [ 2.05883, 2.03842, 2.18355 ]
# Goal position:  [ -9.69322, -4.03628, 2.5 ]
# Distance to goal:  13.23301513209072
# Reward:  -242.30787708498818
# Accumulated Reward:  -1396.9538159285285
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.8456, -3.64879, 3 ]
# Final position of art:  [ 3.13101, -2.6808, 2.71368 ]
# Goal position:  [ -9.90447, 4.40986, 3 ]
# Distance to goal:  14.841932860047596
# Reward:  -258.41974233137876
# Accumulated Reward:  -1453.5170634597782
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.56859, -10.4846, 3 ]
# Final position of art:  [ 2.78105, -10.2214, 2.64115 ]
# Goal position:  [ -0.512234, 10.4875, 2.5 ]
# Distance to goal:  20.969590493352566
# Reward:  -319.6816532047586
# Accumulated Reward:  -2260.4898100172704
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.2595, -4.95093, 3 ]
# Final position of art:  [ 5.58059, -2.61105, 2.40678 ]
# Goal position:  [ -7.88064, 3.36773, 3 ]
# Distance to goal:  14.741183917074762
# Reward:  -257.4109230463325
# Accumulated Reward:  -1553.7207503077573
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4312, -1.20027, 3 ]
# Final position of art:  [ 4.06961, -0.743818, 2.51178 ]
# Goal position:  [ -9.95634, -8.34671, 3 ]
# Distance to goal:  15.961500987486625
# Reward:  -269.83813638977307
# Accumulated Reward:  -665.393074194143
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.2897, -4.89394, 3 ]
# Final position of art:  [ 5.50908, -1.0504, 2.53021 ]
# Goal position:  [ -6.18863, 8.48239, 2.5 ]
# Distance to goal:  15.090104467447993
# Reward:  -260.9487745003935
# Accumulated Reward:  -1097.1588406988544
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.57508, -8.18647, 3 ]
# Final position of art:  [ 6.76181, -6.35695, 2.3081 ]
# Goal position:  [ -9.73624, 3.93137, 2.5 ]
# Distance to goal:  19.44407368686212
# Reward:  -304.4414070802825
# Accumulated Reward:  -2040.839965521372
# --------------------------------------------------------------
# Test Level level_5.bmp: Success rate = 0.06
#
# Mean Traversal Time: 8.33 s Average Roll/Pitch Angle: 9.79/5.33 deg
#
# Average Roll/Pitch Angle: 9.79/5.33 deg
# Variance Roll/Pitch Angle: 63.22/21.87 deg
#
# Checkpoint ppo_checkpoint_stage4_iter49.zip: Success rate on last test level = 0.06
#
# Mean success rate across all evaluated checkpoints = 0.17647058823529416
# Overall success rates for all checkpoints in run 3: [0.0, 0.12, 0.08, 0.3, 0.38, 0.38, 0.28, 0.4, 0.28, 0.32, 0.2, 0.02, 0.1, 0.02, 0.0, 0.06, 0.06]
# Mean success rate across all evaluated checkpoints in run 3: 0.17647058823529416

# %% [markdown]
# Test Specified Model

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from gym_chrono.envs.wheeled.off_road_artACL import off_road_art
from gymnasium.utils.env_checker import check_env
import torch as th
import numpy as np
import os
import re
import matplotlib.pyplot as plt
import csv
from torch.utils.tensorboard import SummaryWriter

def evaluate_model(env, model, num_trials=50, max_steps=1000, render=False):
    success_count = 0
    traversal_times = []
    episode_roll_means = []
    episode_pitch_means = []

    for trial in range(num_trials):
        obs, _ = env.reset(seed=trial)
        if render:
            env.render('follow')
        
        step_count = 0
        roll_angles = []
        pitch_angles = []
        
        while step_count < max_steps:
            action, _states = model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, info = env.step(action)
            if render:
                env.render('follow')
            
            step_count += 1
            
            # Collect roll and pitch angles at each step
            euler_angles = env.m_vehicle.GetVehicle().GetRot().Q_to_Euler123()
            roll_angles.append(np.degrees(abs(euler_angles.x)))
            pitch_angles.append(np.degrees(abs(euler_angles.y)))
            
            if terminated or truncated:
                if terminated and step_count < 200:  # Successful trial
                    success_count += 1
                    traversal_times.append(env.m_system.GetChTime())
                break
        
        # Calculate mean roll and pitch angles for this episode
        episode_roll_means.append(np.mean(roll_angles))
        episode_pitch_means.append(np.mean(pitch_angles))

    mean_traversal_time = np.mean(traversal_times) if traversal_times else 0
    var_traversal_time = np.var(traversal_times) if traversal_times else 0
    avg_roll_angle = np.mean(episode_roll_means)
    var_roll_angle = np.var(episode_roll_means)
    avg_pitch_angle = np.mean(episode_pitch_means)
    var_pitch_angle = np.var(episode_pitch_means)

    return success_count, mean_traversal_time, var_traversal_time, avg_roll_angle, var_roll_angle, avg_pitch_angle, var_pitch_angle

def evaluate_on_test_levels(env, model, test_level_dir, num_trials=50, max_steps=1000, render=False, writer=None, iteration=None):
    level_file = "level_5.bmp"
    level_path = os.path.join(test_level_dir, level_file)
    env.terrain_file = [level_path]
    env.update_terrain_stage(level_index=0)
        
    # Evaluate a single model on a given terrain
    success_count, mean_traversal_time, var_traversal_time, avg_roll_angle, var_roll_angle, avg_pitch_angle, var_pitch_angle = evaluate_model(env, model, num_trials=num_trials, max_steps=max_steps, render=render)
    success_rate = float(success_count) / num_trials
    
    # Log the success rate for each test level
    if writer is not None and iteration is not None:
        writer.add_scalar(f'Success Rate/Test Level 5', success_rate, iteration)
    
    print(f"Test Level {level_file}: Success rate = {success_rate}\n")
    print(f"Mean Traversal Time: {mean_traversal_time:.2f} s", f"Average Roll/Pitch Angle: {avg_roll_angle:.2f}/{avg_pitch_angle:.2f} deg\n")
    print(f"Average Roll/Pitch Angle: {avg_roll_angle:.2f}/{avg_pitch_angle:.2f} deg")
    print(f"Variance Roll/Pitch Angle: {var_roll_angle:.2f}/{var_pitch_angle:.2f} deg\n")

    return success_rate, mean_traversal_time, var_traversal_time, avg_roll_angle, var_roll_angle, avg_pitch_angle, var_pitch_angle

# Set up TensorBoard writer and environment
checkpoint_file = './TestModel/ppo_checkpoint_iter24_level64'
test_level_dir = '../TestLevels'

# Ensure environment is correctly initialized
env = off_road_art()

for run_index in range(1, 4):  # Run 3 evaluations
    log_dir = f'./TestModel/run{run_index}_logs-24'
    writer = SummaryWriter(log_dir)
    
    csv_file = f'./TestModel/run{run_index}_results-24.csv'
    model = PPO.load(checkpoint_file, env)
    
    with open(csv_file, mode='w', newline='') as file:
        writer_csv = csv.writer(file)
        writer_csv.writerow(["Iteration", "Success Rate", "Mean Traversal Time", "Var Traversal Time", "Average Roll Angle", "Var Roll Angle", "Average Pitch Angle", "Var Pitch Angle"])
        
        # Evaluate the model on the test levels
        success_rate, mean_traversal_time, var_traversal_time, avg_roll_angle, var_roll_angle, avg_pitch_angle, var_pitch_angle = evaluate_on_test_levels(
            env, model, test_level_dir, num_trials=50, max_steps=1000, render=False, writer=writer, iteration=24)
        
        writer_csv.writerow([24, success_rate, mean_traversal_time, var_traversal_time, avg_roll_angle, var_roll_angle, avg_pitch_angle, var_pitch_angle])
    
    print(f"Run {run_index}: Success rate = {success_rate}, Mean Traversal Time = {mean_traversal_time}")
    
    writer.close()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Terrain loaded from /home/tong/Documents/gym_chrono/envs/wheeled/../data/terrain_bitmaps/Automatic-CL/TrainLevels/../TestLevels/level_5.bmp
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -7.34469, 4.78818, 3 ]
# Final position of art:  [ 0.205283, 0.397682, 2.65827 ]
# Goal position:  [ 7.67097, -9.70266, 3 ]
# Distance to goal:  12.564633832471388
# Reward:  -235.64768315479586
# Accumulated Reward:  -883.127030027535
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 11.8648, -3.59666, 3 ]
# Goal position:  [ -5.18005, 9.13329, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.8887, 3.53037, 3 ]
# Final position of art:  [ 5.54191, 0.362017, 2.20413 ]
# Goal position:  [ -10.099, -2.87397, 2.5 ]
# Distance to goal:  15.974917341253965
# Reward:  -269.7364048634546
# Accumulated Reward:  -1445.6492696980017
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4833, 0.59215, 3 ]
# Final position of art:  [ 6.00489, -1.03322, 2.32675 ]
# Goal position:  [ -9.72685, -3.95454, 2.5 ]
# Distance to goal:  16.00161507032456
# Reward:  -270.01102800301413
# Accumulated Reward:  -928.7630218607312
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -6.03625, 6.75787, 3 ]
# Final position of art:  [ 4.46618, -0.534697, 2.50168 ]
# Goal position:  [ 8.91556, -7.80224, 3 ]
# Distance to goal:  8.535957472372738
# Reward:  -195.52225002803726
# Accumulated Reward:  -491.56238959445653
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -8.48387, -0.58175, 3 ]
# Final position of art:  [ 0.759103, -0.931782, 2.86033 ]
# Goal position:  [ 10.4923, -8.77038, 3 ]
# Distance to goal:  12.497953952866535
# Reward:  -234.97885474553019
# Accumulated Reward:  -1338.9460112971483
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -6.11287, -6.66568, 3 ]
# Final position of art:  [ -1.57899, -2.21119, 2.24756 ]
# Goal position:  [ 9.50721, 8.23101, 3 ]
# Distance to goal:  15.248265917605528
# Reward:  -262.4581541795609
# Accumulated Reward:  -1508.377162497954
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -6.99174, 5.42205, 3 ]
# Final position of art:  [ 1.18478, 1.18847, 2.40631 ]
# Goal position:  [ 7.89628, -8.30348, 3 ]
# Distance to goal:  11.640179736520304
# Reward:  -226.76963401964474
# Accumulated Reward:  -868.9890501148514
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4496, -1.02743, 3 ]
# Final position of art:  [ 6.42083, -1.3511, 2.26502 ]
# Goal position:  [ -8.97714, -5.44619, 2.5 ]
# Distance to goal:  15.93494327582418
# Reward:  -269.5937673826728
# Accumulated Reward:  -1364.5503143121537
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.9539, -3.34205, 3 ]
# Final position of art:  [ 3.00409, -2.72084, 2.75126 ]
# Goal position:  [ -10.3772, -1.60116, 2.5 ]
# Distance to goal:  13.43040960767723
# Reward:  -244.30405299249483
# Accumulated Reward:  -1328.0270153217693
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -7.52111, 4.42702, 3 ]
# Final position of art:  [ 0.454152, 0.546474, 2.66443 ]
# Goal position:  [ 7.21893, -10.2516, 3 ]
# Distance to goal:  12.74651128539242
# Reward:  -239.2100736493657
# Accumulated Reward:  -1515.5458624212827
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4935, -0.368644, 3 ]
# Final position of art:  [ 2.8204, -1.63806, 2.81069 ]
# Goal position:  [ -10.3648, -1.67985, 2.5 ]
# Distance to goal:  13.188878961454073
# Reward:  -241.88790867636027
# Accumulated Reward:  -1188.7707662157397
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -8.49999, 0.0127655, 3 ]
# Final position of art:  [ 1.01613, -0.834956, 2.88604 ]
# Goal position:  [ 9.35564, -9.6948, 3 ]
# Distance to goal:  12.167880886238757
# Reward:  -231.3733835000663
# Accumulated Reward:  -1115.977713874163
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.06652, 9.19676, 3 ]
# Final position of art:  [ 3.52291, -0.240873, 2.53661 ]
# Goal position:  [ -7.27519, -7.5711, 2.5 ]
# Distance to goal:  13.051156266980826
# Reward:  -240.6190480971069
# Accumulated Reward:  -1132.1121157798677
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.412, -4.65443, 3 ]
# Final position of art:  [ 2.52786, -1.01319, 2.78856 ]
# Goal position:  [ -10.49, -0.457846, 2.5 ]
# Distance to goal:  13.032905401702134
# Reward:  -240.32912557601767
# Accumulated Reward:  -1149.078376691483
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -5.35775, 7.49089, 3 ]
# Final position of art:  [ 12.0257, -6.04674, 2.2406 ]
# Goal position:  [ 9.56505, -9.51164, 3 ]
# Distance to goal:  4.317035045965148
# Reward:  -153.1696507986797
# Accumulated Reward:  -240.6430208212139
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -1.28153, -9.97404, 3 ]
# Goal position:  [ -6.65196, 10.4946, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.3019, 2.03016, 3 ]
# Final position of art:  [ 8.61227, 1.27169, 2.17661 ]
# Goal position:  [ -8.51251, -6.14713, 2.5 ]
# Distance to goal:  18.665513197648103
# Reward:  -296.1793050117829
# Accumulated Reward:  -1313.4873859366835
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -6.33982, 6.37945, 3 ]
# Goal position:  [ 10.2716, -5.74614, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -7.10544, 5.22885, 3 ]
# Final position of art:  [ -0.205629, 1.64937, 2.40769 ]
# Goal position:  [ 9.69322, -6.03453, 3 ]
# Distance to goal:  12.545135219905866
# Reward:  -235.45243111562496
# Accumulated Reward:  -1444.185971830946
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -8.49042, 0.448392, 3 ]
# Goal position:  [ 9.14416, 10.0671, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.3274, -9.5668, 3 ]
# Final position of art:  [ 4.54883, -5.87347, 2.25539 ]
# Goal position:  [ -5.08834, 8.88473, 3 ]
# Distance to goal:  17.64182447311052
# Reward:  -286.3599512936867
# Accumulated Reward:  -1326.3042912427718
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.3284, -1.89074, 3 ]
# Final position of art:  [ 1.84407, -0.0601074, 2.67422 ]
# Goal position:  [ -8.33312, 6.3882, 2.5 ]
# Distance to goal:  12.04932775588613
# Reward:  -231.50900233052204
# Accumulated Reward:  -1254.499536152559
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -8.12197, -2.79208, 3 ]
# Final position of art:  [ -8.49085, -2.83209, 2.26408 ]
# Goal position:  [ 8.99547, 10.021, 3 ]
# Distance to goal:  21.71436277337813
# Reward:  -327.3834316326428
# Accumulated Reward:  -2156.565698636117
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 4.47502, 10.2041, 3 ]
# Goal position:  [ 9.44441, -10.27, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -8.13513, -2.74391, 3 ]
# Goal position:  [ 8.92927, 9.61414, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -5.8721, 6.94839, 3 ]
# Goal position:  [ 10.0337, -5.33842, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.66626, -8.1124, 3 ]
# Final position of art:  [ 6.65936, -6.39046, 2.33437 ]
# Goal position:  [ -6.10818, 8.5405, 2.5 ]
# Distance to goal:  19.646147306900748
# Reward:  -306.46149720631615
# Accumulated Reward:  -2027.887481264443
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4718, 0.768353, 3 ]
# Final position of art:  [ 3.05107, -2.33609, 2.7765 ]
# Goal position:  [ -10.1858, -2.54939, 2.5 ]
# Distance to goal:  13.241477504066214
# Reward:  -242.4169230330947
# Accumulated Reward:  -1231.763610460307
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 3.83465, -10.3385, 3 ]
# Goal position:  [ -7.21821, 7.62544, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.33638, -10.4946, 3 ]
# Final position of art:  [ 2.08568, -9.05734, 2.63308 ]
# Goal position:  [ -4.7561, 8.62778, 3 ]
# Distance to goal:  18.965972342165536
# Reward:  -299.6581275247021
# Accumulated Reward:  -2010.7899202921312
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -8.38317, 1.56196, 3 ]
# Final position of art:  [ -0.970139, 0.750121, 2.45541 ]
# Goal position:  [ 10.0935, -6.40268, 3 ]
# Distance to goal:  13.185747774039546
# Reward:  -223.87304992414033
# Accumulated Reward:  -1249.7990894240106
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -3.53818, -8.92068, 3 ]
# Goal position:  [ 5.39363, 10.1074, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 3.42225, -10.4032, 3 ]
# Final position of art:  [ 1.89607, -3.40755, 2.8616 ]
# Goal position:  [ -2.6098, 10.1705, 2.5 ]
# Distance to goal:  14.310727209289166
# Reward:  -253.11542906126016
# Accumulated Reward:  -1418.8378591463993
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -2.89442, -9.28949, 3 ]
# Final position of art:  [ -1.05313, -4.18735, 2.3485 ]
# Goal position:  [ 10.3148, 9.48482, 3 ]
# Distance to goal:  17.792763585504428
# Reward:  -287.92701442626617
# Accumulated Reward:  -1572.514281138069
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.95008, -10.0771, 3 ]
# Final position of art:  [ 3.53939, -4.80758, 2.49974 ]
# Goal position:  [ -0.795525, 10.4698, 2.5 ]
# Distance to goal:  15.880506354059529
# Reward:  -268.77789969667174
# Accumulated Reward:  -1278.2514325306947
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.86407, -9.30542, 3 ]
# Final position of art:  [ 3.74278, -5.84044, 2.38166 ]
# Goal position:  [ -8.23217, 6.51778, 2.5 ]
# Distance to goal:  17.208689073411172
# Reward:  -262.64299028075317
# Accumulated Reward:  -981.7163676637183
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 3.98595, 10.3105, 3 ]
# Final position of art:  [ 3.69726, 9.86316, 2.36996 ]
# Goal position:  [ -8.67785, -6.09203, 3 ]
# Distance to goal:  20.201692697413446
# Reward:  -312.0163327468251
# Accumulated Reward:  -2208.42978349613
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -6.46728, -6.20928, 3 ]
# Final position of art:  [ 3.14853, 4.93067, 2.1218 ]
# Goal position:  [ 9.98031, 7.48981, 3 ]
# Distance to goal:  7.348037810314308
# Reward:  -183.35802280335537
# Accumulated Reward:  -633.234681682792
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -7.83742, -3.67085, 3 ]
# Final position of art:  [ -1.87838, -1.28274, 2.18325 ]
# Goal position:  [ 9.66439, 9.95926, 3 ]
# Distance to goal:  16.13335862897034
# Reward:  -271.2112738684428
# Accumulated Reward:  -1511.339854004378
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.61225, -10.4821, 3 ]
# Final position of art:  [ 2.71712, -10.2274, 2.66232 ]
# Goal position:  [ -7.13824, 7.70036, 2.5 ]
# Distance to goal:  20.458733781406483
# Reward:  -314.5641038759918
# Accumulated Reward:  -2277.8285405798306
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.60325, 8.16376, 3 ]
# Final position of art:  [ 3.6923, 1.68583, 2.34182 ]
# Goal position:  [ -8.07714, -6.70894, 2.5 ]
# Distance to goal:  14.457415812616805
# Reward:  -245.54138505403813
# Accumulated Reward:  -743.2056592896239
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 1.49308, 10.4878, 3 ]
# Goal position:  [ -9.96354, -10.2012, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.61403, -8.87314, 3 ]
# Final position of art:  [ 7.02178, -7.78006, 2.38069 ]
# Goal position:  [ -0.878404, 10.4632, 2.5 ]
# Distance to goal:  19.880731859665374
# Reward:  -297.3611473115857
# Accumulated Reward:  -1257.609137922475
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -6.3826, 6.32313, 3 ]
# Final position of art:  [ 0.091291, 1.46198, 2.34167 ]
# Goal position:  [ 6.29602, -9.30724, 3 ]
# Distance to goal:  12.446204776464105
# Reward:  -234.4485411972655
# Accumulated Reward:  -1343.119883582854
# --------------------------------------------------------------
# Failed setting goal randomly, using default
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -8.37878, -1.59092, 3 ]
# Final position of art:  [ -8.34418, -1.51711, 2.36693 ]
# Goal position:  [ -7.44075, 9.45221, 3 ]
# Distance to goal:  11.024652663453644
# Reward:  -220.4610300674984
# Accumulated Reward:  -1738.0967374521065
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -8.32109, -1.93007, 3 ]
# Goal position:  [ 8.48978, 10.3818, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 0.979132, -10.4503, 3 ]
# Final position of art:  [ 1.19008, -10.3193, 2.68139 ]
# Goal position:  [ 1.41438, 9.97795, 3 ]
# Distance to goal:  20.301033551074582
# Reward:  -313.01037425788877
# Accumulated Reward:  -2219.156385506988
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.2793, 2.1416, 3 ]
# Final position of art:  [ 2.87512, -2.03314, 2.86781 ]
# Goal position:  [ -10.0462, -3.05352, 2.5 ]
# Distance to goal:  12.966759448745119
# Reward:  -239.6675372102157
# Accumulated Reward:  -1214.1513867770368
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.44305, 9.51364, 3 ]
# Final position of art:  [ 2.54573, 1.78419, 2.38214 ]
# Goal position:  [ -4.92714, -6.95829, 3 ]
# Distance to goal:  11.517653272702796
# Reward:  -225.1365291867907
# Accumulated Reward:  -872.9666323307936
# --------------------------------------------------------------
# Test Level level_5.bmp: Success rate = 0.22
#
# Mean Traversal Time: 8.51 s Average Roll/Pitch Angle: 7.88/5.55 deg
#
# Average Roll/Pitch Angle: 7.88/5.55 deg
# Variance Roll/Pitch Angle: 35.20/20.62 deg
#
# Run 1: Success rate = 0.22, Mean Traversal Time = 8.509090909090894
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Terrain loaded from /home/tong/Documents/gym_chrono/envs/wheeled/../data/terrain_bitmaps/Automatic-CL/TrainLevels/../TestLevels/level_5.bmp
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -6.54117, -6.10724, 3 ]
# Final position of art:  [ -1.71403, -2.08459, 2.20006 ]
# Goal position:  [ 8.1933, 9.72589, 3 ]
# Distance to goal:  15.436408562848358
# Reward:  -263.8709758377937
# Accumulated Reward:  -1366.9565076611375
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 3.64465, 10.3704, 3 ]
# Final position of art:  [ 1.11957, 1.98875, 2.32672 ]
# Goal position:  [ -9.9907, -4.67232, 3 ]
# Distance to goal:  12.971556858705144
# Reward:  -239.73331753116935
# Accumulated Reward:  -1365.4547655413976
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -8.462, -0.892534, 3 ]
# Final position of art:  [ -1.15907, 0.168908, 2.31433 ]
# Goal position:  [ 10.4031, 8.68242, 3 ]
# Distance to goal:  14.374792814542301
# Reward:  -253.73048943487237
# Accumulated Reward:  -1507.2151193400512
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.00408, 9.70656, 3 ]
# Final position of art:  [ 1.53539, -0.00934884, 2.71259 ]
# Goal position:  [ -7.1557, -7.68414, 2.5 ]
# Distance to goal:  11.596660751255396
# Reward:  -225.96926865023318
# Accumulated Reward:  -1217.495085261037
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.1582, -6.61014, 3 ]
# Final position of art:  [ 4.51857, -2.1312, 2.61617 ]
# Goal position:  [ -6.35521, 10.219, 3 ]
# Distance to goal:  16.45945064389052
# Reward:  -274.56452844627114
# Accumulated Reward:  -1291.381526965911
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -4.97427, -7.84917, 3 ]
# Goal position:  [ 8.09747, 9.65807, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.0033, 3.19135, 3 ]
# Final position of art:  [ 5.5496, 0.356925, 2.19538 ]
# Goal position:  [ -7.81837, -7.00879, 2.5 ]
# Distance to goal:  15.265947547445005
# Reward:  -262.6626247710357
# Accumulated Reward:  -1473.542327079234
# --------------------------------------------------------------
# Failed setting goal randomly, using default
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -4.1929, 8.47927, 3 ]
# Goal position:  [ -6.22425, 6.94538, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 3.63424, 10.372, 3 ]
# Final position of art:  [ 1.8183, 1.72733, 2.21153 ]
# Goal position:  [ -5.90155, -8.68457, 2.5 ]
# Distance to goal:  12.964831236056584
# Reward:  -239.68738875663553
# Accumulated Reward:  -1244.5350477404804
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.2386, -2.32843, 3 ]
# Final position of art:  [ 4.83985, -3.43403, 2.34465 ]
# Goal position:  [ -7.04289, -7.78766, 2.5 ]
# Distance to goal:  12.656135405228305
# Reward:  -236.57411748527517
# Accumulated Reward:  -1294.849303390065
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -1.79042, 9.79197, 3 ]
# Final position of art:  [ 12.3023, -6.13306, 2.24927 ]
# Goal position:  [ 10.2456, -9.67361, 3 ]
# Distance to goal:  4.162848059934611
# Reward:  -151.679397627148
# Accumulated Reward:  -68.21864770405168
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -1.36418, -9.94647, 3 ]
# Final position of art:  [ 0.0637065, -4.76698, 2.50711 ]
# Goal position:  [ 1.84662, 10.3363, 2.5 ]
# Distance to goal:  15.208199053504426
# Reward:  -262.07302835396416
# Accumulated Reward:  -1567.8535241962622
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 0.83501, -10.4352, 3 ]
# Final position of art:  [ -0.248641, -4.32335, 2.27825 ]
# Goal position:  [ 1.15741, 10.436, 2.5 ]
# Distance to goal:  14.827846173538157
# Reward:  -258.2765377674493
# Accumulated Reward:  -1518.16189309708
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -0.541709, -10.1877, 3 ]
# Final position of art:  [ -0.210504, -4.50792, 2.3037 ]
# Goal position:  [ -2.8323, 10.1108, 2.5 ]
# Distance to goal:  14.853247321232814
# Reward:  -258.5110914982846
# Accumulated Reward:  -1631.805717110672
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.75269, -7.08137, 3 ]
# Final position of art:  [ 3.95777, -0.961853, 2.4477 ]
# Goal position:  [ -4.03493, 9.69378, 2.5 ]
# Distance to goal:  13.320227922731265
# Reward:  -243.20805938320711
# Accumulated Reward:  -725.6970338990404
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -7.95782, -3.33044, 3 ]
# Goal position:  [ 9.11103, 9.53486, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 11.143, 5.16284, 3 ]
# Goal position:  [ -10.063, 7.36055, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.40856, -9.52967, 3 ]
# Final position of art:  [ 6.26683, -9.145, 2.37887 ]
# Goal position:  [ -9.98966, 4.49224, 3 ]
# Distance to goal:  21.2281336132908
# Reward:  -322.2807790868894
# Accumulated Reward:  -2137.388790956068
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.00748, -8.61163, 3 ]
# Final position of art:  [ 7.99385, -8.56959, 2.22745 ]
# Goal position:  [ -6.16247, 8.07774, 3 ]
# Distance to goal:  21.86622308032272
# Reward:  -328.6605098462844
# Accumulated Reward:  -2290.035355687485
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -7.67843, -4.07161, 3 ]
# Final position of art:  [ -1.75802, -0.931104, 2.19899 ]
# Goal position:  [ 10.1314, 7.54971, 3 ]
# Distance to goal:  14.626142545754389
# Reward:  -245.59480852692403
# Accumulated Reward:  -756.3004592903599
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.4265, 6.26446, 3 ]
# Final position of art:  [ 3.37276, 1.35483, 2.36564 ]
# Goal position:  [ -9.15976, 2.21684, 3 ]
# Distance to goal:  12.578141018261011
# Reward:  -235.67023764999473
# Accumulated Reward:  -1357.050410762273
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.19465, -9.125, 3 ]
# Final position of art:  [ 5.0676, -5.65449, 2.30616 ]
# Goal position:  [ -3.68941, 9.83048, 2.5 ]
# Distance to goal:  17.790638333989516
# Reward:  -287.8925455479207
# Accumulated Reward:  -1516.7409503602041
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 3.64428, -10.3705, 3 ]
# Final position of art:  [ 3.05995, -5.63008, 2.30828 ]
# Goal position:  [ 3.35022, 9.95118, 2.5 ]
# Distance to goal:  15.585142399256975
# Reward:  -265.84820768764814
# Accumulated Reward:  -1095.0182578998374
# --------------------------------------------------------------
# Failed setting goal randomly, using default
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -8.491, -0.434685, 3 ]
# Final position of art:  [ -1.4641, -0.476712, 2.27562 ]
# Goal position:  [ 7.07789, 1.72495, 3 ]
# Distance to goal:  8.850855098199723
# Reward:  -189.0954397880045
# Accumulated Reward:  -938.4545191761727
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4517, 1.00551, 3 ]
# Final position of art:  [ -12.2775, 3.48763, 2.31015 ]
# Goal position:  [ -8.19574, 6.56353, 2.5 ]
# Distance to goal:  5.114475708911458
# Reward:  -161.12886432505877
# Accumulated Reward:  -126.90129372398484
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.02673, -9.69719, 3 ]
# Final position of art:  [ 3.30143, -4.92264, 2.47717 ]
# Goal position:  [ -10.1269, 5.27104, 3 ]
# Distance to goal:  16.867224746468548
# Reward:  -278.4953994552526
# Accumulated Reward:  -943.2294991719343
# --------------------------------------------------------------
# Failed setting goal randomly, using default
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -8.33661, -1.8451, 3 ]
# Final position of art:  [ -8.25013, -1.83461, 2.3527 ]
# Goal position:  [ 4.91206, 5.42725, 3 ]
# Distance to goal:  15.046499774416546
# Reward:  -260.2995836978482
# Accumulated Reward:  -2139.532234928621
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -5.36933, -7.4795, 3 ]
# Goal position:  [ 8.33838, 7.13957, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -7.14654, -5.15662, 3 ]
# Goal position:  [ 8.36322, 7.63587, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.4934, -6.1735, 3 ]
# Final position of art:  [ 2.9835, -2.71139, 2.76057 ]
# Goal position:  [ -10.4723, 0.762854, 2.5 ]
# Distance to goal:  13.899480533117432
# Reward:  -248.994982126465
# Accumulated Reward:  -1311.894735756804
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 0.212194, -10.3467, 3 ]
# Final position of art:  [ 0.854686, -5.67047, 2.42338 ]
# Goal position:  [ 5.34322, 9.38392, 3 ]
# Distance to goal:  15.719864908558636
# Reward:  -267.2158386717657
# Accumulated Reward:  -1466.60053417477
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 3.10819, 10.4414, 3 ]
# Final position of art:  [ 3.10358, 10.4972, 2.26043 ]
# Goal position:  [ 7.92952, -10.2488, 3 ]
# Distance to goal:  21.312779275447074
# Reward:  -323.12875111347125
# Accumulated Reward:  -1869.1345177971796
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -8.33216, 1.86987, 3 ]
# Final position of art:  [ -1.52993, 0.484106, 2.23403 ]
# Goal position:  [ 9.70681, -6.84687, 3 ]
# Distance to goal:  13.438533602718977
# Reward:  -235.1555948932442
# Accumulated Reward:  -307.9920382112356
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -6.33989, 6.37936, 3 ]
# Final position of art:  [ 1.76243, 1.36486, 2.56373 ]
# Goal position:  [ 6.61058, -9.63529, 3 ]
# Distance to goal:  12.02905632735598
# Reward:  -215.22978553953834
# Accumulated Reward:  -1049.5625845323539
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.3561, -1.73258, 3 ]
# Final position of art:  [ 4.93009, -3.40927, 2.30661 ]
# Goal position:  [ -6.71107, -10.1863, 3 ]
# Distance to goal:  13.48799890497
# Reward:  -244.8460989294499
# Accumulated Reward:  -1329.1879360039622
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.27011, -8.42233, 3 ]
# Final position of art:  [ 6.5637, -6.40227, 2.32635 ]
# Goal position:  [ -1.152, 10.4366, 2.5 ]
# Distance to goal:  18.52323347956859
# Reward:  -295.23210205747193
# Accumulated Reward:  -1869.4632103283589
# --------------------------------------------------------------
# Failed setting goal randomly, using default
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -8.45821, -0.935887, 3 ]
# Final position of art:  [ -1.40735, -0.630674, 2.30121 ]
# Goal position:  [ 9.98377, -3.71538, 3 ]
# Distance to goal:  11.82206420245787
# Reward:  -228.2123713465098
# Accumulated Reward:  -1269.4620092377017
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.28779, 10.4961, 3 ]
# Final position of art:  [ 1.43468, 1.76192, 2.33398 ]
# Goal position:  [ -6.6909, -8.09209, 2.5 ]
# Distance to goal:  12.773174556522717
# Reward:  -237.83650054728275
# Accumulated Reward:  -1436.2784165645949
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.362, 4.7542, 3 ]
# Final position of art:  [ -0.133648, 0.277338, 2.22652 ]
# Goal position:  [ -9.95426, 3.75929, 3 ]
# Distance to goal:  10.448287531829706
# Reward:  -214.5024276973352
# Accumulated Reward:  -724.7713926545975
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -2.311, 9.5742, 3 ]
# Final position of art:  [ 3.90858, -1.15234, 2.39864 ]
# Goal position:  [ 2.65822, -10.1579, 2.5 ]
# Distance to goal:  9.092559023170853
# Reward:  -200.85872472116273
# Accumulated Reward:  -890.2053048151238
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.414, 6.28123, 3 ]
# Final position of art:  [ 4.74651, -2.38569, 2.2275 ]
# Goal position:  [ -2.09522, -10.2888, 2.5 ]
# Distance to goal:  10.45672931192719
# Reward:  -214.51576674513495
# Accumulated Reward:  -1281.3414938400708
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 0.653493, 10.4133, 3 ]
# Final position of art:  [ 2.91295, 1.37843, 2.44881 ]
# Goal position:  [ 0.0194945, -10.5, 2.5 ]
# Distance to goal:  12.2258498524712
# Reward:  -232.25951227927212
# Accumulated Reward:  -1209.5630440578698
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -8.45855, 0.932047, 3 ]
# Final position of art:  [ -8.54895, 0.945007, 2.25783 ]
# Goal position:  [ 10.1284, 10.1507, 3 ]
# Distance to goal:  20.836036192132585
# Reward:  -318.32077746428206
# Accumulated Reward:  -2215.0787087417757
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.37676, 9.01889, 3 ]
# Final position of art:  [ 3.88442, 1.7925, 2.28305 ]
# Goal position:  [ -5.24266, -9.0975, 2.5 ]
# Distance to goal:  14.210652423823086
# Reward:  -252.10069065237462
# Accumulated Reward:  -1310.931840274296
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.43043, 9.51952, 3 ]
# Final position of art:  [ 2.83859, 2.24049, 2.26309 ]
# Goal position:  [ 0.452156, -9.69364, 3 ]
# Distance to goal:  12.192692084120015
# Reward:  -231.85441569549192
# Accumulated Reward:  -808.1190076252315
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.29106, 9.58315, 3 ]
# Final position of art:  [ 2.67642, -1.82673, 2.92232 ]
# Goal position:  [ -6.83197, -9.31521, 3 ]
# Distance to goal:  12.10342241908802
# Reward:  -231.0341371609532
# Accumulated Reward:  -1098.5139713025858
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -4.04661, 8.5842, 3 ]
# Goal position:  [ 8.2419, -7.77583, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 1.37075, 10.4811, 3 ]
# Goal position:  [ 9.45514, -8.82227, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.2895, 2.09196, 3 ]
# Final position of art:  [ 2.96154, -2.35968, 2.84512 ]
# Goal position:  [ -7.122, -7.71538, 2.5 ]
# Distance to goal:  11.422805022898599
# Reward:  -224.22785147037342
# Accumulated Reward:  -1110.0660640070585
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.48471, -8.25824, 3 ]
# Final position of art:  [ 6.66121, -6.32075, 2.32275 ]
# Goal position:  [ -2.1608, 10.2753, 2.5 ]
# Distance to goal:  18.79592469165386
# Reward:  -297.96115977087857
# Accumulated Reward:  -2021.2678061889817
# --------------------------------------------------------------
# Test Level level_5.bmp: Success rate = 0.16
#
# Mean Traversal Time: 8.26 s Average Roll/Pitch Angle: 7.29/3.88 deg
#
# Average Roll/Pitch Angle: 7.29/3.88 deg
# Variance Roll/Pitch Angle: 20.64/12.62 deg
#
# Run 2: Success rate = 0.16, Mean Traversal Time = 8.262500000000095
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Terrain loaded from /home/tong/Documents/gym_chrono/envs/wheeled/../data/terrain_bitmaps/Automatic-CL/TrainLevels/../TestLevels/level_5.bmp
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -5.11478, 7.72204, 3 ]
# Goal position:  [ 7.9653, -9.01538, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.1105, 2.83344, 3 ]
# Final position of art:  [ 5.5498, 0.328767, 2.20822 ]
# Goal position:  [ -10.1011, -2.8668, 2.5 ]
# Distance to goal:  15.976432925205197
# Reward:  -269.782492445275
# Accumulated Reward:  -1424.2825526519684
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4348, -1.16835, 3 ]
# Final position of art:  [ 4.72272, -3.38679, 2.44398 ]
# Goal position:  [ -7.09142, -9.60338, 3 ]
# Distance to goal:  13.361480751465756
# Reward:  -243.60811392051087
# Accumulated Reward:  -925.9479951874665
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -8.49428, 0.346488, 3 ]
# Final position of art:  [ 0.741782, -1.0323, 2.88594 ]
# Goal position:  [ 9.96149, -8.86256, 3 ]
# Distance to goal:  12.096646102982863
# Reward:  -230.9626024601547
# Accumulated Reward:  -1356.9964624001595
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -4.62396, 8.14697, 3 ]
# Goal position:  [ 8.71612, -7.53035, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.5372, 6.11283, 3 ]
# Final position of art:  [ 3.94341, 0.199407, 2.50772 ]
# Goal position:  [ -10.4974, -0.232517, 2.5 ]
# Distance to goal:  14.447299563020941
# Reward:  -254.5415542440282
# Accumulated Reward:  -1370.434958909982
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4894, 0.471229, 3 ]
# Final position of art:  [ 4.67424, -2.34534, 2.66305 ]
# Goal position:  [ -8.09154, -6.69156, 2.5 ]
# Distance to goal:  13.486341083811418
# Reward:  -246.11006118724447
# Accumulated Reward:  -1544.6699394236261
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -5.73506, 7.10063, 3 ]
# Goal position:  [ 10.0042, -6.12773, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.2813, -4.90989, 3 ]
# Final position of art:  [ 6.06072, -1.92044, 2.39492 ]
# Goal position:  [ -6.35183, 8.36087, 2.5 ]
# Distance to goal:  16.11794000091578
# Reward:  -271.0214125825827
# Accumulated Reward:  -1565.6552666930647
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -7.58886, -4.27828, 3 ]
# Final position of art:  [ 0.47241, -0.216117, 2.60425 ]
# Goal position:  [ 7.82499, 9.54604, 3 ]
# Distance to goal:  12.227707564521099
# Reward:  -232.27702154965016
# Accumulated Reward:  -1213.3808240033359
# --------------------------------------------------------------
# ...
# Final position of art:  [ 0.651465, -3.14209, 2.70585 ]
# Goal position:  [ 1.91247, 10.3244, 2.5 ]
# Distance to goal:  13.52693210231392
# Reward:  -245.55760962162745
# Accumulated Reward:  -1490.751151656692
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -7.5909, 4.2737, 3 ]
# Final position of art:  [ -0.700249, 1.24739, 2.30078 ]
# Goal position:  [ 9.34696, -8.97485, 3 ]
# Distance to goal:  14.350248738023982
# Reward:  -253.5017828438315
# Accumulated Reward:  -1378.4853032134815
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -1.3074, 9.9655, 3 ]
# Final position of art:  [ 5.76203, -6.12544, 2.27402 ]
# Goal position:  [ 3.83529, -10.1337, 3 ]
# Distance to goal:  4.506195007692003
# Reward:  -155.0621715365512
# Accumulated Reward:  -395.77411677446304
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -5.4845, -7.36425, 3 ]
# Goal position:  [ 8.28254, 9.69531, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.83524, -9.32043, 3 ]
# Final position of art:  [ 4.30356, -5.4313, 2.62524 ]
# Goal position:  [ 1.17183, 10.4344, 2.5 ]
# Distance to goal:  16.17232491122679
# Reward:  -263.5038052908228
# Accumulated Reward:  -516.7137414538313
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -7.24474, 4.97844, 3 ]
# Final position of art:  [ 0.176114, 1.64614, 2.22121 ]
# Goal position:  [ 8.87729, -8.06741, 3 ]
# Distance to goal:  13.064077233577095
# Reward:  -240.67600211039525
# Accumulated Reward:  -1429.6169310463727
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -6.57361, -6.06162, 3 ]
# Goal position:  [ 9.73667, 9.54646, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 0.858409, 10.4378, 3 ]
# Goal position:  [ -9.5918, -8.12428, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -3.56462, 8.90421, 3 ]
# Final position of art:  [ 12.1163, -11.9894, 2.31168 ]
# Goal position:  [ 9.29321, -7.79987, 3 ]
# Distance to goal:  5.098602280891245
# Reward:  -161.14717927820288
# Accumulated Reward:  -24.82922264855722
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -5.72875, -7.10749, 3 ]
# Final position of art:  [ -1.42154, -2.81078, 2.33024 ]
# Goal position:  [ 8.00549, 7.64543, 3 ]
# Distance to goal:  14.09431785957366
# Reward:  -250.92241079519218
# Accumulated Reward:  -1440.5564653410443
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.0845, -5.26518, 3 ]
# Final position of art:  [ 2.74033, -1.86875, 2.86911 ]
# Goal position:  [ -7.46434, 7.38469, 2.5 ]
# Distance to goal:  13.780335491721962
# Reward:  -247.80351532586633
# Accumulated Reward:  -1296.461281473651
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -6.80949, -5.71339, 3 ]
# Goal position:  [ 10.3204, 6.53628, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 2.52253, -10.487, 3 ]
# Final position of art:  [ 2.83976, -9.05769, 2.43839 ]
# Goal position:  [ 6.70505, 9.14243, 3 ]
# Distance to goal:  18.614516225443058
# Reward:  -296.14536659390126
# Accumulated Reward:  -1876.0170857756984
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -7.26426, 4.94201, 3 ]
# Goal position:  [ 10.0111, -8.2144, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 3.79818, 10.3449, 3 ]
# Final position of art:  [ 3.58387, 10.0851, 2.32483 ]
# Goal position:  [ -3.27931, -9.97477, 2.5 ]
# Distance to goal:  21.202208058871555
# Reward:  -322.02132786220153
# Accumulated Reward:  -2248.4548954553447
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.10601, 10.0301, 3 ]
# Final position of art:  [ 4.46387, 8.85244, 2.37792 ]
# Goal position:  [ 4.9228, -10.3938, 3 ]
# Distance to goal:  19.26171298296713
# Reward:  -302.4739658092109
# Accumulated Reward:  -1776.9520626721187
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ 8.9753, 7.84826, 3 ]
# Goal position:  [ -0.114079, -10.4994, 2.5 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 4.02752, 10.3024, 3 ]
# Final position of art:  [ 2.70763, -1.45835, 2.83195 ]
# Goal position:  [ -4.99947, -9.23338, 2.5 ]
# Distance to goal:  10.95265236222997
# Reward:  -219.52598714592062
# Accumulated Reward:  -1053.261260952992
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.16999, 7.6708, 3 ]
# Final position of art:  [ 3.23161, 1.55117, 2.25885 ]
# Goal position:  [ -9.9778, -3.27009, 2.5 ]
# Distance to goal:  14.06382361837643
# Reward:  -250.64227010094004
# Accumulated Reward:  -1343.273403886103
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -3.48996, -8.95044, 3 ]
# Goal position:  [ 4.83114, 9.24978, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -8.31583, 1.95798, 3 ]
# Final position of art:  [ 0.879577, -1.01425, 2.89417 ]
# Goal position:  [ 8.32882, -9.88944, 3 ]
# Distance to goal:  11.587555126706446
# Reward:  -225.87481276123964
# Accumulated Reward:  -1276.214753070589
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -3.99799, 8.61825, 3 ]
# Goal position:  [ 9.90093, -6.95057, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.4995, 0.0987601, 3 ]
# Final position of art:  [ 4.64515, -3.24616, 2.45718 ]
# Goal position:  [ -6.50846, -8.23953, 2.5 ]
# Distance to goal:  12.220422965761035
# Reward:  -232.20446928182645
# Accumulated Reward:  -1107.3623598486142
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -2.36675, -9.5489, 3 ]
# Final position of art:  [ -0.70977, -4.51349, 2.36801 ]
# Goal position:  [ 0.0364833, 10.4999, 2.5 ]
# Distance to goal:  15.032536850502163
# Reward:  -260.33869598930005
# Accumulated Reward:  -1314.3832645443083
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -5.57056, 7.27576, 3 ]
# Final position of art:  [ -5.63437, 7.44586, 2.31346 ]
# Goal position:  [ 9.17536, -8.58455, 3 ]
# Distance to goal:  21.8351494257052
# Reward:  -328.5112220412156
# Accumulated Reward:  -1940.2010934996147
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 5.80815, 9.78509, 3 ]
# Final position of art:  [ 2.05144, 2.01981, 2.19034 ]
# Goal position:  [ -9.95607, -9.62654, 3 ]
# Distance to goal:  16.74733379629619
# Reward:  -277.4249416823385
# Accumulated Reward:  -1407.0898855389432
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 11.2006, 5.05957, 3 ]
# Final position of art:  [ 1.35832, 0.601565, 2.3978 ]
# Goal position:  [ -10.2938, 2.07081, 2.5 ]
# Distance to goal:  11.74479843994651
# Reward:  -206.63184431036925
# Accumulated Reward:  -192.22269873092418
# --------------------------------------------------------------
# Failed setting goal randomly, using default
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Goal Reached
# Initial position:  [ -7.68714, -4.05083, 3 ]
# Goal position:  [ 0.446433, 2.2237, 3 ]
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 6.92556, -9.27302, 3 ]
# Final position of art:  [ 6.82536, -9.09356, 2.41337 ]
# Goal position:  [ -10.1633, 2.63749, 2.5 ]
# Distance to goal:  20.645607177232552
# Reward:  -316.46643037853426
# Accumulated Reward:  -2119.123604806036
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 7.3361, 9.04301, 3 ]
# Final position of art:  [ 3.88673, 0.794034, 2.42453 ]
# Goal position:  [ -1.3224, -9.24306, 3 ]
# Distance to goal:  11.322964482887585
# Reward:  -223.27155657543432
# Accumulated Reward:  -1340.5319158079712
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 12.3921, 1.50147, 3 ]
# Final position of art:  [ 5.46981, 0.441018, 2.27754 ]
# Goal position:  [ -7.90696, -0.609439, 3 ]
# Distance to goal:  13.437387771153974
# Reward:  -244.41573627707686
# Accumulated Reward:  -1398.6016287878124
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 10.3454, 6.37217, 3 ]
# Final position of art:  [ 4.15454, 0.153945, 2.48675 ]
# Goal position:  [ -8.54168, -8.3572, 3 ]
# Distance to goal:  15.293691127386923
# Reward:  -262.9656738341657
# Accumulated Reward:  -1312.8263970723813
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.45102, -8.28458, 3 ]
# Final position of art:  [ 6.60091, -6.38793, 2.32108 ]
# Goal position:  [ -10.4928, -0.388637, 2.5 ]
# Distance to goal:  18.116806370032226
# Reward:  -291.1680476944929
# Accumulated Reward:  -2022.6490654397644
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 8.32186, -8.38356, 3 ]
# Final position of art:  [ 6.72616, -6.34803, 2.31369 ]
# Goal position:  [ -4.37711, 9.54416, 2.5 ]
# Distance to goal:  19.387594651112167
# Reward:  -303.87594393235514
# Accumulated Reward:  -2016.990636261565
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ 9.63795, -7.20497, 3 ]
# Final position of art:  [ 4.99832, -3.46672, 2.5068 ]
# Goal position:  [ -9.08897, 5.25744, 2.5 ]
# Distance to goal:  16.56993602600108
# Reward:  -275.75713883287756
# Accumulated Reward:  -1451.7151130854295
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -1.56219, 9.87729, 3 ]
# Final position of art:  [ -1.50135, 9.78297, 2.31091 ]
# Goal position:  [ 0.945786, -10.4573, 2.5 ]
# Distance to goal:  20.388561712521984
# Reward:  -303.2443916152629
# Accumulated Reward:  -1030.3468477972344
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -5.92517, -6.88779, 3 ]
# Final position of art:  [ -1.455, -2.86711, 2.31381 ]
# Goal position:  [ 10.3712, 5.02841, 3 ]
# Distance to goal:  14.236213191489773
# Reward:  -252.3696941812404
# Accumulated Reward:  -1357.4980668080707
# --------------------------------------------------------------
# warning cbtCollisionDispatcher::needsCollision: static-static collision!
# --------------------------------------------------------------
# Time out
# Initial position:  [ -2.69528, -9.39172, 3 ]
# Final position of art:  [ -0.796659, -4.34394, 2.40411 ]
# Goal position:  [ 9.62433, 7.17541, 3 ]
# Distance to goal:  15.54500971336079
# Reward:  -265.4495617057367
# Accumulated Reward:  -1653.11986485564
# --------------------------------------------------------------
# Test Level level_5.bmp: Success rate = 0.28
#
# Mean Traversal Time: 7.89 s Average Roll/Pitch Angle: 7.68/4.50 deg
#
# Average Roll/Pitch Angle: 7.68/4.50 deg
# Variance Roll/Pitch Angle: 28.83/10.69 deg
#
# Run 3: Success rate = 0.28, Mean Traversal Time = 7.885714285714241
